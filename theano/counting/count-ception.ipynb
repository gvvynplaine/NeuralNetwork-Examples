# %% [markdown]
# This code is for:
#
# J. P. Cohen, H. Z. Lo, and Y. Bengio, “Count-ception: Counting by Fully Convolutional Redundant Counting,” 2017.
# https://arxiv.org/abs/1703.08710
#
#
# Here is a video of the learning in progress:
# [![](http://img.youtube.com/vi/ej5bj0mlQq8/0.jpg)](https://www.youtube.com/watch?v=ej5bj0mlQq8)
#
# The cell dataset used in this work is available from [VGG](http://www.robots.ox.ac.uk/~vgg/research/counting/cells.zip) and [Academic Torrents](http://academictorrents.com/details/b32305598175bb8e03c5f350e962d772a910641c)

# %%
import sys,os,time,random
import numpy as np
import matplotlib
matplotlib.use('Agg');
import matplotlib.pyplot as plt
plt.set_cmap('jet');

import theano
import theano.tensor as T 
import lasagne

import skimage
from skimage.io import imread, imsave
import pickle
import scipy

from os import walk
print "theano",theano.version.full_version
print "lasagne",lasagne.__version__
# Out:
# theano 0.9.0.dev-RELEASE
# lasagne 0.2.dev1

# %%
# %matplotlib inline

# %%
if len(sys.argv) == 3 or sys.argv[0] == "jupyter": #on jupyter
    sys.argv = ['jupyter', 'jupyter','0', '32', '1', '0.005', 'sq','1']

print sys.argv;

seed = int(sys.argv[2])
print "seed",seed           #### Random seed for shuffling data and network weights
nsamples = int(sys.argv[3])
print "nsamples",nsamples   #### Number of samples (N) in train and valid
stride = int(sys.argv[4])
print "stride",stride       #### The stride at the initial layer

lr_param = float(sys.argv[5])
print "lr_param",lr_param   #### This will set the learning rate 

kern = sys.argv[6]
print "kern",kern           #### This can be gaus or sq
cov = int(sys.argv[7])
print "cov",cov             #### This is the covariance when kern=gaus
# Out:
# ['jupyter', 'jupyter', '0', '32', '1', '0.005', 'sq', '1']
# seed 0
# nsamples 32
# stride 1
# lr_param 0.005
# kern sq
# cov 1

# %%
scale = 1
patch_size = 32
framesize = 256
noutputs = 1

# %%
paramfilename = str(scale) + "-" + str(patch_size) + "-cell-" + kern + str(cov) + "_cell_data.p"
datasetfilename = str(scale) + "-" + str(patch_size) + "-" + str(framesize) + "-" + kern + str(stride) + "-cell-" + str(cov) + "-dataset.p"
print paramfilename
print datasetfilename
# Out:
# 1-32-cell-sq1_cell_data.p
# 1-32-256-sq1-cell-1-dataset.p

# %%
random.seed(seed)
np.random.seed(seed)
lasagne.random.set_rng(np.random.RandomState(seed))

# %%
from lasagne.layers.normalization import BatchNormLayer
from lasagne.layers import InputLayer, ConcatLayer, Conv2DLayer

input_var = T.tensor4('inputs')
input_var_ex = T.ivector('input_var_ex')

def ConvFactory(data, num_filter, filter_size, stride=1, pad=0, nonlinearity=lasagne.nonlinearities.leaky_rectify):
    data = lasagne.layers.batch_norm(Conv2DLayer(
        data, num_filters=num_filter,
        filter_size=filter_size,
        stride=stride, pad=pad,
        nonlinearity=nonlinearity,
        W=lasagne.init.GlorotUniform(gain='relu')))
    return data

def SimpleFactory(data, ch_1x1, ch_3x3):
    conv1x1 = ConvFactory(data=data, filter_size=1, pad=0, num_filter=ch_1x1)
    conv3x3 = ConvFactory(data=data, filter_size=3, pad=1, num_filter=ch_3x3) 
    concat = ConcatLayer([conv1x1, conv3x3])
    return concat


input_shape = (None, 1, framesize, framesize)
img = InputLayer(shape=input_shape, input_var=input_var[input_var_ex])
net = img


net = ConvFactory(net, filter_size=3, num_filter=64, pad=patch_size)
print net.output_shape
net = SimpleFactory(net, 16, 16)
print net.output_shape
net = SimpleFactory(net, 16, 32)
print net.output_shape
net = ConvFactory(net, filter_size=14, num_filter=16) 
print net.output_shape
net = SimpleFactory(net, 112, 48)
print net.output_shape
net = SimpleFactory(net, 64, 32)
print net.output_shape
net = SimpleFactory(net, 40, 40)
print net.output_shape
net = SimpleFactory(net, 32, 96)
print net.output_shape
net = ConvFactory(net, filter_size=18, num_filter=32) 
print net.output_shape
net = ConvFactory(net, filter_size=1, pad=0, num_filter=64)
print net.output_shape
net = ConvFactory(net, filter_size=1, pad=0, num_filter=64)
print net.output_shape
net = ConvFactory(net, filter_size=1, num_filter=1, stride=stride)
print net.output_shape
# Out:
# (None, 64, 318, 318)
# (None, 32, 318, 318)
# (None, 48, 318, 318)
# (None, 16, 305, 305)
# (None, 160, 305, 305)
# (None, 96, 305, 305)
# (None, 80, 305, 305)
# (None, 128, 305, 305)
# (None, 32, 288, 288)
# (None, 64, 288, 288)
# (None, 64, 288, 288)
# (None, 1, 288, 288)

# %%
output_shape = lasagne.layers.get_output_shape(net)
real_input_shape = (None, input_shape[1], input_shape[2]+2*patch_size, input_shape[3]+2*patch_size)
print "real_input_shape:",real_input_shape,"-> output_shape:",output_shape
# Out:
# real_input_shape: (None, 1, 320, 320) -> output_shape: (None, 1, 288, 288)

# %%
print "network output size should be",(input_shape[2]+2*patch_size)-(patch_size)
# Out:
# network output size should be 288

# %%
if (kern == "sq"):
    ef = ((patch_size/stride)**2.0)
elif (kern == "gaus"):
    ef = 1.0
print "ef", ef

prediction = lasagne.layers.get_output(net, deterministic=True)
prediction_count = (prediction/ef).sum(axis=(2,3))

classify = theano.function([input_var, input_var_ex], prediction)
# Out:
# ef 1024.0

# %%
train_start_time = time.time()
print classify(np.zeros((1,1,framesize,framesize), dtype=theano.config.floatX), [0]).shape
print time.time() - train_start_time, "sec"

train_start_time = time.time()
print classify(np.zeros((1,1,framesize,framesize), dtype=theano.config.floatX), [0]).shape
print time.time() - train_start_time, "sec"
# Out:
# (1, 1, 286, 286)
# 1.11842298508 sec
# (1, 1, 286, 286)
# 0.237368106842 sec

# %%
def genGausImage(framesize, mx, my, cov=1):
    x, y = np.mgrid[0:framesize, 0:framesize]
    pos = np.dstack((x, y))
    mean = [mx, my]
    cov = [[cov, 0], [0, cov]]
    rv = scipy.stats.multivariate_normal(mean, cov).pdf(pos)
    return rv/rv.sum()

def getDensity(width, markers):
    gaus_img = np.zeros((width,width))
    for k in range(width):
        for l in range(width):
            if (markers[k,l] > 0.5):
                gaus_img += genGausImage(len(markers),k-patch_size/2,l-patch_size/2,cov)
    return gaus_img

def getMarkersCells(labelPath):        
    lab = imread(labelPath)[:,:,0]/255
    return np.pad(lab,patch_size, "constant")

def getCellCountCells(markers, (x,y,h,w), scale):
    types = [0] * noutputs
    types[0] = markers[y:y+w,x:x+h].sum()
    return types

def getLabelsCells(img, labelPath, base_x, base_y, stride):
    
    width = ((img.shape[0])/stride)
    print "label size: ", width
    markers = getMarkersCells(labelPath)
    labels = np.zeros((noutputs, width, width))
    
    
    if (kern == "sq"):
        for x in range(0,width):
            for y in range(0,width):

                count = getCellCountCells(markers,(base_x + x*stride,base_y + y*stride,patch_size,patch_size),scale)  
                for i in range(0,noutputs):
                    labels[i][y][x] = count[i]
    
    elif (kern == "gaus"):
        for i in range(0,noutputs):
            labels[i] = getDensity(width, markers[base_y:base_y+width,base_x:base_x+width])
    

    count_total = getCellCountCells(markers,(base_x,base_y,framesize+patch_size,framesize+patch_size),scale)
    return labels, count_total

def getTrainingExampleCells(img_raw, labelPath, base_x,  base_y, stride):
    
    img = img_raw[base_y:base_y+framesize,base_x:base_x+framesize]
    img_pad = np.pad(img,(patch_size)/2, "constant")
    labels, count  = getLabelsCells(img_pad, labelPath, base_x, base_y, stride)
    return img, labels, count

# %%
# ## code to debug data generation
# %matplotlib inline
# plt.rcParams['figure.figsize'] = (18, 9)
# imgPath,labelPath,x,y = imgs[0][0],imgs[0][1], 0, 0

# print imgPath, labelPath
# # img_raw = imread(imgPath)[1]


# im = imread(imgPath)
# img_raw_raw = im.mean(axis=(2)) #grayscale

# img_raw = scipy.misc.imresize(img_raw_raw, (img_raw_raw.shape[0]/scale,img_raw_raw.shape[1]/scale))
# print img_raw_raw.shape," ->>>>", img_raw.shape

    
# #img_raw = scipy.misc.imresize(img_raw_raw, (img_raw_raw.shape[0]/scale,img_raw_raw.shape[1]/scale))
# print "img_raw",img_raw.shape
# img, lab, count = getTrainingExampleCells(img_raw, labelPath, x, y, stride)
# print "count", count

# markers = markers = getMarkersCells(labelPath)
# count = getCellCountCells(markers, (0,0,framesize,framesize), scale)
# print "count", count

# pcount = classify([[img]], [0])[0]

# lab_est = [(l.sum()/ef).astype(np.int) for l in lab]
# pred_est = [(l.sum()/ef).astype(np.int) for l in pcount]

# print "label est ",lab_est," --> predicted est ",pred_est

# fig = plt.Figure(figsize=(18, 9), dpi=160)
# gcf = plt.gcf()
# gcf.set_size_inches(18, 15)
# fig.set_canvas(gcf.canvas)

# ax2 = plt.subplot2grid((2,4), (0, 0), colspan=2)
# ax3 = plt.subplot2grid((2,4), (0, 2), colspan=3)
# ax4 = plt.subplot2grid((2,4), (1, 2), colspan=3)
# ax5 = plt.subplot2grid((2,4), (1, 0), rowspan=1)
# ax6 = plt.subplot2grid((2,4), (1, 1), rowspan=1)

# ax2.set_title("Input Image")
# ax2.imshow(img, interpolation='none', cmap='Greys_r')
# ax3.set_title("Regression target, {}x{} sliding window.".format(patch_size, patch_size))
# ax3.imshow(np.concatenate((lab),axis=1), interpolation='none')
# ax4.set_title("Predicted counts")
# ax4.imshow(np.concatenate((pcount),axis=1), interpolation='none')

# ax5.set_title("Real " + str(lab_est))
# ax5.set_ylim((0, np.max(lab_est)*2))
# ax5.set_xticks(np.arange(0, noutputs, 1.0))
# ax5.bar(range(noutputs),lab_est, align='center')
# ax6.set_title("Pred " + str(pred_est))
# ax6.set_ylim((0, np.max(lab_est)*2))
# ax6.set_xticks(np.arange(0, noutputs, 1.0))
# ax6.bar(range(noutputs),pred_est, align='center')

# #plt.imshow(img, interpolation='none', cmap='Greys_r')

# #plt.imshow(np.concatenate((lab),axis=1), interpolation='none')


# #fig.savefig('images-cell/image-' + str(i) + "-" + name + '.png')

# %%
import glob
imgs = []
for filename in glob.iglob('cells/*cell.png'):
    xml = filename.split("cell.png")[0] + "dots.png"
    imgs.append([filename,xml])

# %%
if len(imgs) == 0:
    print "Error loading data"

# %%
for path in imgs: 
    if (not os.path.isfile(path[0])):
        print path, "bad", path[0]
    if (not os.path.isfile(path[1])):
        print path, "bad", path[1]

# %%
if (os.path.isfile(datasetfilename)):
    print "reading", datasetfilename
    dataset = pickle.load(open(datasetfilename, "rb" ))
else:
    dataset = []
    print len(imgs)
    for path in imgs: 

        imgPath = path[0]
        print imgPath

        im = imread(imgPath)
        img_raw_raw = im.mean(axis=(2)) #grayscale

        img_raw = scipy.misc.imresize(img_raw_raw, (img_raw_raw.shape[0]/scale,img_raw_raw.shape[1]/scale))
        print img_raw_raw.shape," ->>>>", img_raw.shape

        labelPath = path[1]
        for base_x in range(0,img_raw.shape[0],framesize):
            for base_y in range(0,img_raw.shape[1],framesize):
                img, lab, count = getTrainingExampleCells(img_raw, labelPath, base_y, base_x, stride)
                
                lab_est = [(l.sum()/ef).astype(np.int) for l in lab]
                
                assert np.allclose(count,lab_est, 1)
                
                dataset.append((img,lab,count))
                print "img shape", img.shape, "label shape", lab.shape, "count ", count, "lab_est", lab_est
                sys.stdout.flush()
                    
    print "writing", datasetfilename
    out = open(datasetfilename, "wb",0)
    pickle.dump(dataset, out)
    out.close()
print "DONE"

# %%
# %matplotlib inline
# plt.rcParams['figure.figsize'] = (18, 9)
# plt.imshow(lab[0])

# %%
np_dataset = np.asarray(dataset)

#random.shuffle(np_dataset)
np.random.shuffle(np_dataset)

np_dataset = np.rollaxis(np_dataset,1,0)
np_dataset_x = np.asarray([[n] for n in np_dataset[0]],dtype=theano.config.floatX)
np_dataset_y = np.asarray([n for n in np_dataset[1]],dtype=theano.config.floatX)
np_dataset_c = np.asarray([n for n in np_dataset[2]],dtype=theano.config.floatX)

print "np_dataset_x", np_dataset_x.shape
print "np_dataset_y", np_dataset_y.shape
print "np_dataset_c", np_dataset_c.shape
# Out:
# np_dataset_x (200, 1, 256, 256)
# np_dataset_y (200, 1, 286, 286)
# np_dataset_c (200, 1)

# %%
del np_dataset

# %%
length = len(np_dataset_x)

n = nsamples

np_dataset_x_train = np_dataset_x[0:n]
np_dataset_y_train = np_dataset_y[0:n]
np_dataset_c_train = np_dataset_c[0:n]
print "np_dataset_x_train", len(np_dataset_x_train)

np_dataset_x_valid = np_dataset_x[n:2*n]
np_dataset_y_valid = np_dataset_y[n:2*n]
np_dataset_c_valid = np_dataset_c[n:2*n]
print "np_dataset_x_valid", len(np_dataset_x_valid)

np_dataset_x_test = np_dataset_x[100:]
np_dataset_y_test = np_dataset_y[100:]
np_dataset_c_test = np_dataset_c[100:]
print "np_dataset_x_test", len(np_dataset_x_test)
# Out:
# np_dataset_x_train 32
# np_dataset_x_valid 32
# np_dataset_x_test 100

# %%
np_dataset_x_train.shape
# Out:
# (32, 1, 256, 256)

# %%
np_dataset_x_train[:4,0].shape
# Out:
# (4, 256, 256)

# %%
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Example images")
plt.imshow(np.concatenate(np_dataset_x_train[:5,0],axis=1), interpolation='none', cmap='Greys_r')

# %%
plt.title("Example images")
plt.imshow(np.concatenate(np_dataset_y_train[:5,0],axis=1), interpolation='none')

# %%
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Counts in each image")
plt.bar(range(len(np_dataset_c_train)),np_dataset_c_train);

# %%
print "Total cells in training", np.sum(np_dataset_c_train[0:], axis=0)
print "Total cells in validation", np.sum(np_dataset_c_valid[0:], axis=0)
print "Total cells in testing", np.sum(np_dataset_c_test[0:], axis=0)
# Out:
# Total cells in training [ 5486.]
# Total cells in validation [ 5834.]
# Total cells in testing [ 17026.]

# %%
#to make video: ffmpeg -i image-0-%d-cell.png -vcodec libx264 aout.mp4
def processImages(name, i):
    fig = plt.Figure(figsize=(18, 9), dpi=160)
    gcf = plt.gcf()
    gcf.set_size_inches(18, 15)
    fig.set_canvas(gcf.canvas)
    
    (img, lab, count) = dataset[i]
    
    print str(i),count
    pcount = classify([[img]], [0])[0]
    
    lab_est = [(l.sum()/(ef)).astype(np.int) for l in lab]
    pred_est = [(l.sum()/(ef)).astype(np.int) for l in pcount]
    
    print str(i),"label est ",lab_est," --> predicted est ",pred_est

    ax2 = plt.subplot2grid((2,4), (0, 0), colspan=2)
    ax3 = plt.subplot2grid((2,4), (0, 2), colspan=3)
    ax4 = plt.subplot2grid((2,4), (1, 2), colspan=3)
    ax5 = plt.subplot2grid((2,4), (1, 0), rowspan=1)
    ax6 = plt.subplot2grid((2,4), (1, 1), rowspan=1)

    ax2.set_title("Input Image")
    ax2.imshow(img, interpolation='none', cmap='Greys_r')
    ax3.set_title("Regression target, {}x{} sliding window.".format(patch_size, patch_size))
    ax3.imshow(np.concatenate((lab),axis=1), interpolation='none')
    ax4.set_title("Predicted counts")
    ax4.imshow(np.concatenate((pcount),axis=1), interpolation='none')

    ax5.set_title("Real " + str(lab_est))
    ax5.set_ylim((0, np.max(lab_est)*2))
    ax5.set_xticks(np.arange(0, noutputs, 1.0))
    ax5.bar(range(noutputs),lab_est, align='center')
    ax6.set_title("Pred " + str(pred_est))
    ax6.set_ylim((0, np.max(lab_est)*2))
    ax6.set_xticks(np.arange(0, noutputs, 1.0))
    ax6.bar(range(noutputs),pred_est, align='center')
    
    fig.savefig('images-cell/image-' + str(i) + "-" + name + '.png')

# %%
import pickle, os

directory = "network-temp/"
ext = "countception.p"

if not os.path.exists(directory):
    os.makedirs(directory)
    
def save_network(net,name):
    pkl_params = lasagne.layers.get_all_param_values(net, trainable=True)
    out = open(directory + str(name) + ext, "w", 0) #bufsize=0
    pickle.dump(pkl_params, out)
    out.close()

def load_network(net,name):
    all_param_values = pickle.load(open(directory + str(name) + ext, "r" ))
    lasagne.layers.set_all_param_values(net, all_param_values, trainable=True)

# %%
def re_init_network(net, re_seed):
    
    np.random.seed(re_seed)
    lasagne.random.set_rng(np.random.RandomState(re_seed))
    
    old = lasagne.layers.get_all_param_values(net, trainable=True)
    new = []
    for layer in old:
        shape = layer.shape
        if len(shape)<2:
            shape = (shape[0], 1)
        W= lasagne.init.GlorotUniform()(shape)
        if W.shape != layer.shape:
            W = np.squeeze(W, axis= 1)
        new.append(W)
    lasagne.layers.set_all_param_values(net, new, trainable=True)

# %%
#test accuracy
def test_perf(dataset_x, dataset_y, dataset_c):

    testpixelerrors = []
    testerrors = []
    bs = 1
    for i in range(0,len(dataset_x), bs):

        pcount = classify(dataset_x,range(i,i+bs))
        pixelerr = np.abs(pcount - dataset_y[i:i+bs]).mean(axis=(2,3))
        testpixelerrors.append(pixelerr)
        
        pred_est = (pcount/(ef)).sum(axis=(1,2,3))
        err = np.abs(dataset_c[i:i+bs].flatten()-pred_est)
        
        testerrors.append(err)
    
    return np.abs(testpixelerrors).mean(), np.abs(testerrors).mean()

# %%
print "Random performance"
print test_perf(np_dataset_x_train, np_dataset_y_train, np_dataset_c_train)
print test_perf(np_dataset_x_valid, np_dataset_y_valid, np_dataset_c_valid)
print test_perf(np_dataset_x_test, np_dataset_y_test, np_dataset_c_test)
# Out:
# Random performance
# (13.562059, 1059.8879)
# (13.88553, 1085.5143)
# (13.427428, 1049.8357)

# %%
re_init_network(net,seed)

# %%
target_var = T.tensor4('target')
lr = theano.shared(np.array(lr_param, dtype=theano.config.floatX))

#Mean Absolute Error is computed between each count of the count map
l1_loss = T.abs_(prediction - target_var[input_var_ex])

#Mean Absolute Error is computed for the overall image prediction
prediction_count2 =(prediction/ef).sum(axis=(2,3))
mae_loss = T.abs_(prediction_count2 - (target_var[input_var_ex]/ef).sum(axis=(2,3))) 

loss = l1_loss.mean()

params = lasagne.layers.get_all_params(net, trainable=True)
updates = lasagne.updates.adam(loss, params, learning_rate=lr)

train_fn = theano.function([input_var_ex], [loss,mae_loss], updates=updates,
                         givens={input_var:np_dataset_x_train, target_var:np_dataset_y_train})

print "DONE compiling theano functons"
# Out:
# DONE compiling theano functons

# %%
batch_size = 2

print "batch_size", batch_size
print "lr", lr.eval()

best_valid_err = 99999999
best_test_err = 99999999
datasetlength = len(np_dataset_x_train)
print "datasetlength",datasetlength

for epoch in range(1000):
    start_time = time.time()

    epoch_err_pix = []
    epoch_err_pred = []
    todo = range(datasetlength)    
    
    for i in range(0,datasetlength, batch_size):
        ex = todo[i:i+batch_size]

        train_start_time = time.time()
        err_pix,err_pred = train_fn(ex)
        train_elapsed_time = time.time() - train_start_time

        epoch_err_pix.append(err_pix)
        epoch_err_pred.append(err_pred)

    valid_pix_err, valid_err = test_perf(np_dataset_x_valid, np_dataset_y_valid, np_dataset_c_valid)

    # a threshold is used to reduce processing when we are far from the goal
    if (valid_err < 20 and valid_err < best_valid_err):
        best_valid_err = valid_err
        best_test_err = test_perf(np_dataset_x_test, np_dataset_y_test,np_dataset_c_test)
        print "OOO best test (err_pix, err_pred)", best_test_err, ", epoch",epoch
        save_network(net,"best_valid_err")


    elapsed_time = time.time() - start_time
    err = np.mean(epoch_err_pix)
    acc = np.mean(np.concatenate(epoch_err_pred))
    
    if epoch % 5 == 0:
        print "#" + str(epoch) + "# (err_pix:" + str(np.around(err,3)) + ", err_pred:" +  str(np.around(acc,3)) + "), valid (err_pix:" + str(np.around(valid_pix_err,3)) + ", err_pred:" + str(np.around(valid_err,3)) +"), (time:" + str(np.around(elapsed_time,3)) + "sec)"

    #visualize training
    #processImages(str(epoch) + '-cell',0)

print "#####", "best_test_acc", best_test_err, "stride", stride, sys.argv
# Out:
# batch_size 2
# lr 0.00499999988824
# datasetlength 32
# #0# (err_pix:1.541, err_pred:53.851), valid (err_pix:3.741, err_pred:298.036), (time:43.029sec)
# #5# (err_pix:0.874, err_pred:35.682), valid (err_pix:0.73, err_pred:20.061), (time:42.865sec)
# OOO best test (err_pix, err_pred) (0.50669199, 11.709442) , epoch 9
# OOO best test (err_pix, err_pred) (0.47750798, 7.2481031) , epoch 10
# #10# (err_pix:0.513, err_pred:12.082), valid (err_pix:0.506, err_pred:8.431), (time:69.437sec)
# OOO best test (err_pix, err_pred) (0.46782219, 5.4175396) , epoch 11
# #15# (err_pix:0.468, err_pred:13.402), valid (err_pix:0.548, err_pred:21.503), (time:42.689sec)
# #20# (err_pix:0.408, err_pred:9.107), valid (err_pix:0.458, err_pred:13.296), (time:42.662sec)
# #25# (err_pix:0.44, err_pred:19.42), valid (err_pix:0.564, err_pred:36.172), (time:42.65sec)
# OOO best test (err_pix, err_pred) (0.35869297, 5.7435827) , epoch 27
# #30# (err_pix:0.344, err_pred:8.966), valid (err_pix:0.425, err_pred:17.158), (time:42.748sec)
# OOO best test (err_pix, err_pred) (0.33070317, 4.9288797) , epoch 35
# #35# (err_pix:0.341, err_pred:9.62), valid (err_pix:0.354, err_pred:5.466), (time:69.35sec)
# OOO best test (err_pix, err_pred) (0.31988174, 4.2799525) , epoch 40
# #40# (err_pix:0.331, err_pred:10.52), valid (err_pix:0.342, err_pred:4.777), (time:69.5sec)
# #45# (err_pix:0.329, err_pred:11.353), valid (err_pix:0.33, err_pred:9.887), (time:42.716sec)
# #50# (err_pix:0.311, err_pred:9.082), valid (err_pix:0.34, err_pred:8.27), (time:42.625sec)
# #55# (err_pix:0.297, err_pred:8.355), valid (err_pix:0.31, err_pred:8.141), (time:42.69sec)
# OOO best test (err_pix, err_pred) (0.28361911, 3.685411) , epoch 60
# #60# (err_pix:0.283, err_pred:7.439), valid (err_pix:0.303, err_pred:3.782), (time:69.287sec)
# #65# (err_pix:0.281, err_pred:7.923), valid (err_pix:0.299, err_pred:9.847), (time:42.682sec)
# OOO best test (err_pix, err_pred) (0.27103281, 3.1982887) , epoch 68
# #70# (err_pix:0.261, err_pred:6.394), valid (err_pix:0.292, err_pred:4.277), (time:42.714sec)
# #75# (err_pix:0.268, err_pred:8.174), valid (err_pix:0.289, err_pred:10.272), (time:42.688sec)
# OOO best test (err_pix, err_pred) (0.25810286, 2.5851917) , epoch 77
# #80# (err_pix:0.247, err_pred:5.184), valid (err_pix:0.276, err_pred:3.752), (time:42.771sec)
# #85# (err_pix:0.241, err_pred:4.99), valid (err_pix:0.266, err_pred:3.14), (time:42.674sec)
# #90# (err_pix:0.238, err_pred:6.735), valid (err_pix:0.29, err_pred:8.389), (time:42.679sec)
# #95# (err_pix:0.226, err_pred:5.893), valid (err_pix:0.263, err_pred:5.778), (time:42.673sec)
# #100# (err_pix:0.213, err_pred:4.509), valid (err_pix:0.247, err_pred:4.614), (time:42.642sec)
# #105# (err_pix:0.203, err_pred:3.59), valid (err_pix:0.245, err_pred:4.337), (time:42.679sec)
# #110# (err_pix:0.215, err_pred:6.957), valid (err_pix:0.244, err_pred:2.859), (time:42.656sec)
# #115# (err_pix:0.253, err_pred:7.809), valid (err_pix:0.266, err_pred:11.009), (time:42.651sec)
# #120# (err_pix:0.197, err_pred:3.74), valid (err_pix:0.242, err_pred:4.492), (time:42.65sec)
# OOO best test (err_pix, err_pred) (0.22300844, 2.3536808) , epoch 124
# #125# (err_pix:0.187, err_pred:3.247), valid (err_pix:0.232, err_pred:5.185), (time:42.652sec)
# #130# (err_pix:0.237, err_pred:9.229), valid (err_pix:0.266, err_pred:8.891), (time:42.737sec)
# #135# (err_pix:0.229, err_pred:8.745), valid (err_pix:0.276, err_pred:9.432), (time:42.686sec)
# #140# (err_pix:0.205, err_pred:7.382), valid (err_pix:0.24, err_pred:6.897), (time:42.652sec)
# #145# (err_pix:0.176, err_pred:4.639), valid (err_pix:0.224, err_pred:4.263), (time:42.676sec)
# OOO best test (err_pix, err_pred) (0.21724705, 2.2139971) , epoch 146
# OOO best test (err_pix, err_pred) (0.21084824, 2.2307208) , epoch 150
# #150# (err_pix:0.185, err_pred:4.677), valid (err_pix:0.227, err_pred:2.618), (time:69.3sec)
# #155# (err_pix:0.257, err_pred:11.798), valid (err_pix:0.293, err_pred:9.117), (time:42.647sec)
# #160# (err_pix:0.195, err_pred:6.189), valid (err_pix:0.255, err_pred:7.935), (time:42.701sec)
# #165# (err_pix:0.185, err_pred:4.595), valid (err_pix:0.242, err_pred:4.494), (time:42.673sec)
# #170# (err_pix:0.209, err_pred:9.004), valid (err_pix:0.229, err_pred:3.249), (time:42.671sec)
# #175# (err_pix:0.163, err_pred:3.302), valid (err_pix:0.244, err_pred:6.114), (time:42.679sec)
# #180# (err_pix:0.183, err_pred:5.515), valid (err_pix:0.234, err_pred:9.212), (time:42.727sec)
# #185# (err_pix:0.177, err_pred:5.328), valid (err_pix:0.251, err_pred:6.328), (time:42.669sec)
# #190# (err_pix:0.192, err_pred:7.252), valid (err_pix:0.254, err_pred:14.132), (time:42.723sec)
# OOO best test (err_pix, err_pred) (0.21228933, 2.3543501) , epoch 194
# #195# (err_pix:0.189, err_pred:7.431), valid (err_pix:0.249, err_pred:6.418), (time:42.695sec)
# #200# (err_pix:0.159, err_pred:2.696), valid (err_pix:0.226, err_pred:2.628), (time:42.64sec)
# #205# (err_pix:0.194, err_pred:7.799), valid (err_pix:0.231, err_pred:6.325), (time:42.691sec)
# #210# (err_pix:0.151, err_pred:2.793), valid (err_pix:0.222, err_pred:4.452), (time:42.633sec)
# OOO best test (err_pix, err_pred) (0.23302621, 2.2898688) , epoch 215
# #215# (err_pix:0.214, err_pred:9.452), valid (err_pix:0.249, err_pred:2.387), (time:69.335sec)
# OOO best test (err_pix, err_pred) (0.2150047, 2.1785493) , epoch 220
# #220# (err_pix:0.173, err_pred:6.218), valid (err_pix:0.231, err_pred:2.377), (time:69.281sec)
# #225# (err_pix:0.164, err_pred:5.061), valid (err_pix:0.233, err_pred:4.183), (time:42.687sec)
# #230# (err_pix:0.181, err_pred:7.009), valid (err_pix:0.222, err_pred:2.554), (time:42.674sec)
# OOO best test (err_pix, err_pred) (0.21048009, 2.0712147) , epoch 231
# #235# (err_pix:0.162, err_pred:4.195), valid (err_pix:0.245, err_pred:12.579), (time:42.732sec)
# #240# (err_pix:0.167, err_pred:4.997), valid (err_pix:0.24, err_pred:10.756), (time:42.688sec)
# #245# (err_pix:0.15, err_pred:4.511), valid (err_pix:0.265, err_pred:16.615), (time:42.658sec)
# #250# (err_pix:0.164, err_pred:6.558), valid (err_pix:0.25, err_pred:12.608), (time:42.693sec)
# #255# (err_pix:0.166, err_pred:6.953), valid (err_pix:0.262, err_pred:15.106), (time:42.664sec)
# #260# (err_pix:0.165, err_pred:4.202), valid (err_pix:0.301, err_pred:19.526), (time:42.657sec)
# #265# (err_pix:0.208, err_pred:8.851), valid (err_pix:0.294, err_pred:16.433), (time:42.678sec)
# #270# (err_pix:0.172, err_pred:5.058), valid (err_pix:0.261, err_pred:13.992), (time:42.669sec)
# #275# (err_pix:0.206, err_pred:9.705), valid (err_pix:0.318, err_pred:21.525), (time:42.65sec)
# #280# (err_pix:0.159, err_pred:4.967), valid (err_pix:0.317, err_pred:21.874), (time:42.68sec)
# #285# (err_pix:0.224, err_pred:9.669), valid (err_pix:0.243, err_pred:8.689), (time:42.702sec)
# #290# (err_pix:0.235, err_pred:12.614), valid (err_pix:0.237, err_pred:3.947), (time:42.634sec)
# OOO best test (err_pix, err_pred) (0.21227998, 2.1168861) , epoch 292
# #295# (err_pix:0.194, err_pred:8.696), valid (err_pix:0.272, err_pred:11.403), (time:42.738sec)
# #300# (err_pix:0.171, err_pred:7.776), valid (err_pix:0.298, err_pred:15.33), (time:42.727sec)
# #305# (err_pix:0.135, err_pred:1.979), valid (err_pix:0.211, err_pred:2.859), (time:42.64sec)
# #310# (err_pix:0.12, err_pred:1.931), valid (err_pix:0.21, err_pred:6.027), (time:42.721sec)
# #315# (err_pix:0.143, err_pred:5.147), valid (err_pix:0.219, err_pred:4.789), (time:42.746sec)
# #320# (err_pix:0.203, err_pred:10.129), valid (err_pix:0.272, err_pred:7.806), (time:42.695sec)
# #325# (err_pix:0.136, err_pred:4.106), valid (err_pix:0.215, err_pred:2.807), (time:42.697sec)
# #330# (err_pix:0.178, err_pred:8.911), valid (err_pix:0.244, err_pred:4.127), (time:42.661sec)
# #335# (err_pix:0.165, err_pred:6.449), valid (err_pix:0.235, err_pred:8.679), (time:42.685sec)
# #340# (err_pix:0.138, err_pred:4.587), valid (err_pix:0.252, err_pred:14.483), (time:42.653sec)
# #345# (err_pix:0.15, err_pred:5.402), valid (err_pix:0.222, err_pred:6.008), (time:42.677sec)
# OOO best test (err_pix, err_pred) (0.19678116, 1.9575537) , epoch 347
# #350# (err_pix:0.173, err_pred:8.711), valid (err_pix:0.314, err_pred:16.271), (time:42.673sec)
# #355# (err_pix:0.158, err_pred:7.619), valid (err_pix:0.225, err_pred:8.582), (time:42.696sec)
# #360# (err_pix:0.148, err_pred:6.357), valid (err_pix:0.214, err_pred:3.996), (time:42.638sec)
# #365# (err_pix:0.121, err_pred:3.157), valid (err_pix:0.22, err_pred:2.303), (time:42.708sec)
# #370# (err_pix:0.115, err_pred:2.481), valid (err_pix:0.219, err_pred:9.553), (time:42.647sec)
# #375# (err_pix:0.162, err_pred:7.723), valid (err_pix:0.274, err_pred:11.856), (time:42.729sec)
# #380# (err_pix:0.113, err_pred:2.884), valid (err_pix:0.214, err_pred:7.593), (time:42.717sec)
# #385# (err_pix:0.139, err_pred:5.621), valid (err_pix:0.225, err_pred:3.753), (time:42.684sec)
# #390# (err_pix:0.137, err_pred:5.907), valid (err_pix:0.234, err_pred:5.563), (time:42.731sec)
# #395# (err_pix:0.122, err_pred:3.768), valid (err_pix:0.241, err_pred:13.001), (time:42.689sec)
# #400# (err_pix:0.123, err_pred:4.517), valid (err_pix:0.244, err_pred:7.49), (time:42.654sec)
# #405# (err_pix:0.122, err_pred:4.457), valid (err_pix:0.219, err_pred:6.95), (time:42.703sec)
# #410# (err_pix:0.14, err_pred:6.036), valid (err_pix:0.219, err_pred:3.999), (time:42.635sec)
# #415# (err_pix:0.097, err_pred:1.518), valid (err_pix:0.205, err_pred:2.384), (time:42.659sec)
# #420# (err_pix:0.094, err_pred:1.319), valid (err_pix:0.205, err_pred:6.173), (time:42.663sec)
# OOO best test (err_pix, err_pred) (0.19093862, 2.0717666) , epoch 422
# #425# (err_pix:0.089, err_pred:1.695), valid (err_pix:0.203, err_pred:4.192), (time:42.646sec)
# OOO best test (err_pix, err_pred) (0.19533689, 1.8686152) , epoch 426
# #430# (err_pix:0.085, err_pred:1.399), valid (err_pix:0.208, err_pred:4.079), (time:42.734sec)
# #435# (err_pix:0.097, err_pred:2.077), valid (err_pix:0.233, err_pred:12.936), (time:42.701sec)
# #440# (err_pix:0.112, err_pred:3.976), valid (err_pix:0.24, err_pred:12.759), (time:42.661sec)
# #445# (err_pix:0.12, err_pred:3.629), valid (err_pix:0.227, err_pred:6.814), (time:42.644sec)
# #450# (err_pix:0.123, err_pred:2.88), valid (err_pix:0.226, err_pred:2.424), (time:42.653sec)
# #455# (err_pix:0.131, err_pred:5.064), valid (err_pix:0.259, err_pred:8.012), (time:42.658sec)
# #460# (err_pix:0.137, err_pred:5.98), valid (err_pix:0.237, err_pred:5.284), (time:42.662sec)
# #465# (err_pix:0.132, err_pred:5.173), valid (err_pix:0.223, err_pred:9.422), (time:42.633sec)
# #470# (err_pix:0.104, err_pred:2.622), valid (err_pix:0.216, err_pred:9.635), (time:42.641sec)
# #475# (err_pix:0.123, err_pred:5.34), valid (err_pix:0.25, err_pred:8.175), (time:42.661sec)
# #480# (err_pix:0.122, err_pred:5.076), valid (err_pix:0.235, err_pred:12.796), (time:42.658sec)
# #485# (err_pix:0.109, err_pred:4.197), valid (err_pix:0.228, err_pred:4.427), (time:42.646sec)
# #490# (err_pix:0.099, err_pred:2.369), valid (err_pix:0.214, err_pred:6.642), (time:42.635sec)
# #495# (err_pix:0.09, err_pred:2.217), valid (err_pix:0.212, err_pred:3.085), (time:42.629sec)
# #500# (err_pix:0.108, err_pred:3.703), valid (err_pix:0.255, err_pred:16.163), (time:42.657sec)
# #505# (err_pix:0.101, err_pred:3.848), valid (err_pix:0.225, err_pred:2.9), (time:42.742sec)
# #510# (err_pix:0.113, err_pred:4.68), valid (err_pix:0.255, err_pred:15.393), (time:42.702sec)
# #515# (err_pix:0.096, err_pred:2.108), valid (err_pix:0.209, err_pred:3.05), (time:42.665sec)
# #520# (err_pix:0.096, err_pred:2.242), valid (err_pix:0.214, err_pred:4.24), (time:42.627sec)
# #525# (err_pix:0.108, err_pred:3.719), valid (err_pix:0.246, err_pred:14.385), (time:42.691sec)
# #530# (err_pix:0.094, err_pred:2.778), valid (err_pix:0.215, err_pred:2.456), (time:42.629sec)
# #535# (err_pix:0.104, err_pred:4.287), valid (err_pix:0.232, err_pred:9.859), (time:42.641sec)
# #540# (err_pix:0.097, err_pred:3.094), valid (err_pix:0.234, err_pred:12.945), (time:42.666sec)
# #545# (err_pix:0.106, err_pred:3.841), valid (err_pix:0.218, err_pred:7.998), (time:42.657sec)
# #550# (err_pix:0.089, err_pred:2.525), valid (err_pix:0.209, err_pred:3.852), (time:42.676sec)
# #555# (err_pix:0.1, err_pred:3.605), valid (err_pix:0.22, err_pred:2.65), (time:42.707sec)
# #560# (err_pix:0.1, err_pred:3.375), valid (err_pix:0.213, err_pred:5.535), (time:42.71sec)
# #565# (err_pix:0.073, err_pred:1.431), valid (err_pix:0.231, err_pred:11.645), (time:42.685sec)
# #570# (err_pix:0.097, err_pred:3.473), valid (err_pix:0.215, err_pred:3.73), (time:42.668sec)
# #575# (err_pix:0.1, err_pred:2.991), valid (err_pix:0.266, err_pred:16.354), (time:42.688sec)
# #580# (err_pix:0.078, err_pred:2.358), valid (err_pix:0.242, err_pred:13.87), (time:42.766sec)
# #585# (err_pix:0.072, err_pred:1.322), valid (err_pix:0.219, err_pred:10.363), (time:42.685sec)
# #590# (err_pix:0.089, err_pred:2.743), valid (err_pix:0.214, err_pred:6.869), (time:42.701sec)
# #595# (err_pix:0.081, err_pred:2.366), valid (err_pix:0.22, err_pred:8.743), (time:42.674sec)
# #600# (err_pix:0.113, err_pred:4.781), valid (err_pix:0.233, err_pred:11.794), (time:42.686sec)
# #605# (err_pix:0.092, err_pred:2.889), valid (err_pix:0.217, err_pred:6.295), (time:42.732sec)
# #610# (err_pix:0.1, err_pred:3.226), valid (err_pix:0.224, err_pred:11.238), (time:42.736sec)
# #615# (err_pix:0.072, err_pred:1.951), valid (err_pix:0.255, err_pred:16.076), (time:42.749sec)
# #620# (err_pix:0.102, err_pred:4.39), valid (err_pix:0.224, err_pred:2.374), (time:42.641sec)
# #625# (err_pix:0.097, err_pred:3.128), valid (err_pix:0.251, err_pred:15.555), (time:42.647sec)
# #630# (err_pix:0.077, err_pred:1.855), valid (err_pix:0.21, err_pred:7.6), (time:42.682sec)
# #635# (err_pix:0.106, err_pred:4.513), valid (err_pix:0.245, err_pred:14.033), (time:42.627sec)
# #640# (err_pix:0.084, err_pred:1.976), valid (err_pix:0.213, err_pred:3.22), (time:42.671sec)
# #645# (err_pix:0.103, err_pred:4.269), valid (err_pix:0.279, err_pred:18.613), (time:42.739sec)
# #650# (err_pix:0.09, err_pred:2.784), valid (err_pix:0.217, err_pred:2.387), (time:42.705sec)
# #655# (err_pix:0.102, err_pred:2.753), valid (err_pix:0.228, err_pred:10.836), (time:42.627sec)
# #660# (err_pix:0.106, err_pred:4.71), valid (err_pix:0.213, err_pred:2.315), (time:42.668sec)
# #665# (err_pix:0.076, err_pred:1.779), valid (err_pix:0.22, err_pred:11.701), (time:42.726sec)
# #670# (err_pix:0.085, err_pred:3.015), valid (err_pix:0.211, err_pred:3.981), (time:42.67sec)
# #675# (err_pix:0.088, err_pred:3.307), valid (err_pix:0.216, err_pred:3.756), (time:42.714sec)
# #680# (err_pix:0.092, err_pred:2.794), valid (err_pix:0.259, err_pred:16.422), (time:42.694sec)
# #685# (err_pix:0.085, err_pred:2.83), valid (err_pix:0.212, err_pred:3.129), (time:42.65sec)
# #690# (err_pix:0.072, err_pred:2.174), valid (err_pix:0.206, err_pred:3.118), (time:42.768sec)
# #695# (err_pix:0.084, err_pred:3.325), valid (err_pix:0.231, err_pred:5.237), (time:42.686sec)
# #700# (err_pix:0.09, err_pred:2.789), valid (err_pix:0.221, err_pred:8.967), (time:42.71sec)
# #705# (err_pix:0.076, err_pred:2.62), valid (err_pix:0.214, err_pred:2.281), (time:42.655sec)
# #710# (err_pix:0.079, err_pred:2.772), valid (err_pix:0.236, err_pred:6.957), (time:42.7sec)
# #715# (err_pix:0.073, err_pred:1.543), valid (err_pix:0.234, err_pred:6.044), (time:42.676sec)
# #720# (err_pix:0.072, err_pred:1.413), valid (err_pix:0.213, err_pred:2.57), (time:42.643sec)
# #725# (err_pix:0.074, err_pred:1.353), valid (err_pix:0.248, err_pred:7.264), (time:42.649sec)
# #730# (err_pix:0.057, err_pred:0.872), valid (err_pix:0.214, err_pred:3.197), (time:42.707sec)
# #735# (err_pix:0.071, err_pred:2.389), valid (err_pix:0.217, err_pred:2.502), (time:42.714sec)
# #740# (err_pix:0.09, err_pred:3.489), valid (err_pix:0.214, err_pred:2.911), (time:42.718sec)
# #745# (err_pix:0.083, err_pred:1.127), valid (err_pix:0.208, err_pred:2.141), (time:42.651sec)
# #750# (err_pix:0.059, err_pred:1.757), valid (err_pix:0.238, err_pred:7.548), (time:42.651sec)
# #755# (err_pix:0.074, err_pred:2.84), valid (err_pix:0.281, err_pred:13.666), (time:42.661sec)
# #760# (err_pix:0.084, err_pred:2.92), valid (err_pix:0.253, err_pred:2.531), (time:42.691sec)
# #765# (err_pix:0.066, err_pred:2.417), valid (err_pix:0.209, err_pred:6.061), (time:42.719sec)
# #770# (err_pix:0.073, err_pred:1.849), valid (err_pix:0.216, err_pred:2.507), (time:42.702sec)
# #775# (err_pix:0.062, err_pred:1.993), valid (err_pix:0.206, err_pred:2.276), (time:42.658sec)
# #780# (err_pix:0.065, err_pred:1.754), valid (err_pix:0.21, err_pred:2.419), (time:42.703sec)
# #785# (err_pix:0.064, err_pred:1.6), valid (err_pix:0.228, err_pred:4.84), (time:42.657sec)
# #790# (err_pix:0.061, err_pred:1.533), valid (err_pix:0.212, err_pred:2.549), (time:42.681sec)
# #795# (err_pix:0.06, err_pred:1.428), valid (err_pix:0.202, err_pred:5.215), (time:42.63sec)
# #800# (err_pix:0.07, err_pred:2.355), valid (err_pix:0.217, err_pred:2.659), (time:42.636sec)
# #805# (err_pix:0.063, err_pred:1.47), valid (err_pix:0.223, err_pred:3.194), (time:42.699sec)
# #810# (err_pix:0.056, err_pred:1.551), valid (err_pix:0.213, err_pred:4.59), (time:42.689sec)
# #815# (err_pix:0.053, err_pred:1.509), valid (err_pix:0.215, err_pred:2.797), (time:42.667sec)
# #820# (err_pix:0.066, err_pred:1.198), valid (err_pix:0.213, err_pred:7.381), (time:42.649sec)
# #825# (err_pix:0.068, err_pred:2.169), valid (err_pix:0.213, err_pred:2.512), (time:42.717sec)
# #830# (err_pix:0.079, err_pred:2.968), valid (err_pix:0.231, err_pred:2.779), (time:42.674sec)
# #835# (err_pix:0.054, err_pred:1.043), valid (err_pix:0.215, err_pred:8.162), (time:42.668sec)
# #840# (err_pix:0.071, err_pred:2.025), valid (err_pix:0.232, err_pred:10.96), (time:42.692sec)
# #845# (err_pix:0.067, err_pred:2.891), valid (err_pix:0.223, err_pred:11.193), (time:42.618sec)
# #850# (err_pix:0.067, err_pred:2.982), valid (err_pix:0.222, err_pred:8.727), (time:42.671sec)
# #855# (err_pix:0.066, err_pred:2.825), valid (err_pix:0.239, err_pred:13.841), (time:42.747sec)
# #860# (err_pix:0.06, err_pred:1.948), valid (err_pix:0.219, err_pred:9.906), (time:42.645sec)
# #865# (err_pix:0.069, err_pred:2.792), valid (err_pix:0.223, err_pred:9.663), (time:42.652sec)
# #870# (err_pix:0.059, err_pred:1.5), valid (err_pix:0.231, err_pred:12.882), (time:42.673sec)
# #875# (err_pix:0.057, err_pred:1.307), valid (err_pix:0.23, err_pred:13.045), (time:42.712sec)
# #880# (err_pix:0.059, err_pred:1.842), valid (err_pix:0.24, err_pred:13.374), (time:42.623sec)
# #885# (err_pix:0.049, err_pred:1.16), valid (err_pix:0.228, err_pred:12.582), (time:42.675sec)
# #890# (err_pix:0.063, err_pred:1.971), valid (err_pix:0.223, err_pred:9.961), (time:42.638sec)
# #895# (err_pix:0.051, err_pred:2.053), valid (err_pix:0.205, err_pred:6.961), (time:42.662sec)
# #900# (err_pix:0.054, err_pred:1.895), valid (err_pix:0.209, err_pred:4.509), (time:42.724sec)
# #905# (err_pix:0.052, err_pred:1.504), valid (err_pix:0.208, err_pred:4.35), (time:42.662sec)
# #910# (err_pix:0.054, err_pred:1.835), valid (err_pix:0.207, err_pred:4.14), (time:42.694sec)
# #915# (err_pix:0.055, err_pred:1.353), valid (err_pix:0.222, err_pred:9.87), (time:42.676sec)
# #920# (err_pix:0.057, err_pred:2.09), valid (err_pix:0.205, err_pred:5.382), (time:42.716sec)
# #925# (err_pix:0.044, err_pred:0.901), valid (err_pix:0.202, err_pred:2.575), (time:42.67sec)
# #930# (err_pix:0.057, err_pred:2.111), valid (err_pix:0.216, err_pred:2.273), (time:42.681sec)
# #935# (err_pix:0.076, err_pred:3.149), valid (err_pix:0.224, err_pred:5.823), (time:42.634sec)
# #940# (err_pix:0.047, err_pred:1.187), valid (err_pix:0.215, err_pred:3.241), (time:42.702sec)
# OOO best test (err_pix, err_pred) (0.19238263, 2.0253525) , epoch 944
# #945# (err_pix:0.055, err_pred:2.014), valid (err_pix:0.211, err_pred:2.053), (time:42.672sec)
# #950# (err_pix:0.075, err_pred:2.596), valid (err_pix:0.233, err_pred:2.558), (time:42.687sec)
# #955# (err_pix:0.05, err_pred:1.5), valid (err_pix:0.226, err_pred:4.938), (time:42.635sec)
# #960# (err_pix:0.044, err_pred:1.059), valid (err_pix:0.23, err_pred:5.78), (time:42.706sec)
# #965# (err_pix:0.058, err_pred:2.083), valid (err_pix:0.213, err_pred:3.921), (time:42.676sec)
# #970# (err_pix:0.058, err_pred:1.983), valid (err_pix:0.218, err_pred:3.358), (time:42.72sec)
# #975# (err_pix:0.064, err_pred:2.567), valid (err_pix:0.222, err_pred:5.585), (time:42.639sec)
# #980# (err_pix:0.053, err_pred:1.933), valid (err_pix:0.213, err_pred:5.454), (time:42.65sec)
# #985# (err_pix:0.064, err_pred:2.154), valid (err_pix:0.217, err_pred:4.783), (time:42.686sec)
# #990# (err_pix:0.054, err_pred:1.838), valid (err_pix:0.216, err_pred:2.55), (time:42.671sec)
# #995# (err_pix:0.052, err_pred:1.407), valid (err_pix:0.21, err_pred:3.29), (time:42.691sec)
# ##### best_test_acc (0.19238263, 2.0253525) stride 1 ['jupyter', 'jupyter', '0', '32', '1', '0.005', 'sq', '1']

# %%
print "Done"
# Out:
# Done

# %%
#load best network
load_network(net,"best_valid_err")

# %%
def compute_counts(dataset_x):

    bs = 1
    ests = []
    for i in range(0,len(dataset_x), bs):
        pcount = classify(dataset_x,range(i,i+bs))
        pred_est = (pcount/(ef)).sum(axis=(1,2,3))        
        ests.append(pred_est)
    return ests

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Training Data")

pcounts = compute_counts(np_dataset_x_train)
plt.bar(np.arange(len(np_dataset_c_train))-0.1,np_dataset_c_train, width=0.5, label="Real Count");
plt.bar(np.arange(len(np_dataset_c_train))+0.1,pcounts, width=0.5,label="Predicted Count");
plt.tight_layout()
plt.legend()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Valid Data")

pcounts = compute_counts(np_dataset_x_valid)
plt.bar(np.arange(len(np_dataset_c_valid))-0.1,np_dataset_c_valid, width=0.5, label="Real Count");
plt.bar(np.arange(len(np_dataset_c_valid))+0.1,pcounts, width=0.5,label="Predicted Count");
plt.tight_layout()
plt.legend()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Test Data")

pcounts = compute_counts(np_dataset_x_test)
plt.bar(np.arange(len(np_dataset_c_test))-0.1,np_dataset_c_test, width=0.5, label="Real Count");
plt.bar(np.arange(len(np_dataset_c_test))+0.1,pcounts, width=0.5,label="Predicted Count");
plt.tight_layout()
plt.legend()

# %%
# %matplotlib inline
processImages('test',8)
# Out:
# 8 [188]
# 8 label est  [187]  --> predicted est  [187]

# %%
# %matplotlib inline
processImages('test',1)
# Out:
# 1 [197]
# 1 label est  [196]  --> predicted est  [197]

# %%
# %matplotlib inline
processImages('test',2)
# Out:
# 2 [242]
# 2 label est  [241]  --> predicted est  [242]

# %%
# %matplotlib inline
processImages('test',3)
# Out:
# 3 [194]
# 3 label est  [193]  --> predicted est  [194]

# %%
# %matplotlib inline
processImages('test',4)
# Out:
# 4 [238]
# 4 label est  [237]  --> predicted est  [241]

# %%
# %matplotlib inline
processImages('test',5)
# Out:
# 5 [197]
# 5 label est  [196]  --> predicted est  [198]

# %%
# %matplotlib inline
processImages('test',6)
# Out:
# 6 [155]
# 6 label est  [154]  --> predicted est  [151]
