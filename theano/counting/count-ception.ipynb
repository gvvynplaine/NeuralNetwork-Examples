# %% [markdown]
# This code is for:
#
# J. P. Cohen, H. Z. Lo, and Y. Bengio, “Count-ception: Counting by Fully Convolutional Redundant Counting,” 2017.
# https://arxiv.org/abs/1703.08710
#
#
# Here is a video of the learning in progress:
# [![](http://img.youtube.com/vi/ej5bj0mlQq8/0.jpg)](https://www.youtube.com/watch?v=ej5bj0mlQq8)
#
# The cell dataset used in this work is available from [VGG](http://www.robots.ox.ac.uk/~vgg/research/counting/cells.zip) and [Academic Torrents](http://academictorrents.com/details/b32305598175bb8e03c5f350e962d772a910641c)

# %%
import sys,os,time,random
import numpy as np
import matplotlib
matplotlib.use('Agg');
import matplotlib.pyplot as plt
plt.set_cmap('jet');

import theano
import theano.tensor as T 
import lasagne

import skimage
from skimage.io import imread, imsave
import pickle
import scipy

from os import walk
print "theano",theano.version.full_version
print "lasagne",lasagne.__version__
# Out:
# theano 0.9.0.dev-RELEASE
# lasagne 0.2.dev1

# %%
if len(sys.argv) == 3: #on jupyter
    sys.argv = ['jupyter', 'jupyter','0', '32', '1']

print sys.argv;

seed = int(sys.argv[2])
print "seed",seed
nsamples = int(sys.argv[3])
print "nsamples",nsamples
stride = int(sys.argv[4])
print "stride",stride
# Out:
# ['jupyter', 'jupyter', '0', '32', '1']
# seed 0
# nsamples 32
# stride 1

# %%
scale = 1
patch_size = 32
framesize = 256
noutputs = 1

# %%
paramfilename = str(scale) + "-" + str(patch_size) + "-cell2_cell_data.p"
datasetfilename = str(scale) + "-" + str(patch_size) + "-" + str(framesize) + "-" + str(stride) + "-cell2-dataset.p"
print paramfilename
print datasetfilename
# Out:
# 1-32-cell2_cell_data.p
# 1-32-256-1-cell2-dataset.p

# %%
random.seed(seed)
np.random.seed(seed)
lasagne.random.set_rng(np.random.RandomState(seed))

# %%
from lasagne.layers.normalization import BatchNormLayer
from lasagne.layers import InputLayer, ConcatLayer, Conv2DLayer

input_var = T.tensor4('inputs')
input_var_ex = T.ivector('input_var_ex')

def ConvFactory(data, num_filter, filter_size, stride=1, pad=0, nonlinearity=lasagne.nonlinearities.leaky_rectify):
    data = lasagne.layers.batch_norm(Conv2DLayer(
        data, num_filters=num_filter,
        filter_size=filter_size,
        stride=stride, pad=pad,
        nonlinearity=nonlinearity,
        W=lasagne.init.GlorotUniform(gain='relu')))
    return data

def SimpleFactory(data, ch_1x1, ch_3x3):
    conv1x1 = ConvFactory(data=data, filter_size=1, pad=0, num_filter=ch_1x1)
    conv3x3 = ConvFactory(data=data, filter_size=3, pad=1, num_filter=ch_3x3) 
    concat = ConcatLayer([conv1x1, conv3x3])
    return concat


input_shape = (None, 1, framesize, framesize)
img = InputLayer(shape=input_shape, input_var=input_var[input_var_ex])
net = img


net = ConvFactory(net, filter_size=3, num_filter=64, pad=patch_size)
print net.output_shape
net = SimpleFactory(net, 16, 16)
print net.output_shape
net = SimpleFactory(net, 16, 32)
print net.output_shape
net = ConvFactory(net, filter_size=14, num_filter=16) 
print net.output_shape
net = SimpleFactory(net, 112, 48)
print net.output_shape
net = SimpleFactory(net, 64, 32)
print net.output_shape
net = SimpleFactory(net, 40, 40)
print net.output_shape
net = SimpleFactory(net, 32, 96)
print net.output_shape
net = ConvFactory(net, filter_size=17, num_filter=32) 
print net.output_shape
net = ConvFactory(net, filter_size=1, pad=0, num_filter=64)
print net.output_shape
net = ConvFactory(net, filter_size=1, pad=0, num_filter=64)
print net.output_shape
net = ConvFactory(net, filter_size=1, num_filter=1, stride=stride)
print net.output_shape
# Out:
# (None, 64, 318, 318)
# (None, 32, 318, 318)
# (None, 48, 318, 318)
# (None, 16, 305, 305)
# (None, 160, 305, 305)
# (None, 96, 305, 305)
# (None, 80, 305, 305)
# (None, 128, 305, 305)
# (None, 32, 289, 289)
# (None, 64, 289, 289)
# (None, 64, 289, 289)
# (None, 1, 289, 289)

# %%
output_shape = lasagne.layers.get_output_shape(net)
real_input_shape = (None, input_shape[1], input_shape[2]+2*patch_size, input_shape[3]+2*patch_size)
print "real_input_shape:",real_input_shape,"-> output_shape:",output_shape
# Out:
# real_input_shape: (None, 1, 320, 320) -> output_shape: (None, 1, 289, 289)

# %%
print (input_shape[2]+2*patch_size)-(patch_size-1)
# Out:
# 289

# %%
ef = ((patch_size/stride)**2)

prediction = lasagne.layers.get_output(net, deterministic=True)
prediction_count = (prediction/ef).sum(axis=(2,3))

classify = theano.function([input_var, input_var_ex], prediction)

# %%
train_start_time = time.time()
print classify(np.zeros((1,1,framesize,framesize), dtype=theano.config.floatX), [0]).shape
print time.time() - train_start_time, "sec"

train_start_time = time.time()
print classify(np.zeros((1,1,framesize,framesize), dtype=theano.config.floatX), [0]).shape
print time.time() - train_start_time, "sec"
# Out:
# (1, 1, 289, 289)
# 0.417132854462 sec
# (1, 1, 289, 289)
# 0.048898935318 sec

# %%
def getMarkersCells(labelPath):        
    lab = imread(labelPath)[:,:,0]/255
    return np.pad(lab,patch_size, "constant")

def getCellCountCells(markers, (x,y,h,w), scale):

    types = [0] * noutputs
    types[0] = markers[y:y+w,x:x+h].sum()
    return types

def getLabelsCells(img, labelPath, base_x, base_y, stride):
    
    width = ((img.shape[0])/stride)+1
    print "label size: ", width
    labels = np.zeros((noutputs, width, width))
    markers = getMarkersCells(labelPath)
    
    for x in range(0,width):
        for y in range(0,width):
            
            count = getCellCountCells(markers,(base_x + x*stride,base_y + y*stride,patch_size,patch_size),scale)  
            for i in range(0,noutputs):
                labels[i][y][x] = count[i]

    count_total = getCellCountCells(markers,(base_x,base_y,framesize+patch_size,framesize+patch_size),scale)
    return labels, count_total

def getTrainingExampleCells(img_raw, labelPath, base_x,  base_y, stride):
    
    img = img_raw[base_y:base_y+framesize,base_x:base_x+framesize]
    img_pad = np.pad(img,patch_size/2, "constant")
    labels, count  = getLabelsCells(img_pad, labelPath, base_x, base_y, stride)
    return img, labels, count

# %%
import glob
imgs = []
for filename in glob.iglob('cells/*cell.png'):
    xml = filename.split("cell.png")[0] + "dots.png"
    imgs.append([filename,xml])

# %%
for path in imgs: 
    if (not os.path.isfile(path[0])):
        print path, "bad", path[0]
    if (not os.path.isfile(path[1])):
        print path, "bad", path[1]

# %%
if (os.path.isfile(datasetfilename)):
    print "reading", datasetfilename
    dataset = pickle.load(open(datasetfilename, "rb" ))
else:
    dataset = []
    print len(imgs)
    for path in imgs: 

        imgPath = path[0]
        print imgPath

        im = imread(imgPath)
        img_raw_raw = im.mean(axis=(2)) #grayscale

        img_raw = scipy.misc.imresize(img_raw_raw, (img_raw_raw.shape[0]/scale,img_raw_raw.shape[1]/scale))
        print img_raw_raw.shape," ->>>>", img_raw.shape

        print "input image raw shape", img_raw.shape

        labelPath = path[1]
        for base_x in range(0,img_raw.shape[0],framesize):
            for base_y in range(0,img_raw.shape[1],framesize):
                img, lab, count = getTrainingExampleCells(img_raw, labelPath, base_y, base_x, stride)
                print "count ", count
                
                ef = patch_size/stride
                lab_est = [(l.sum()/(ef**2)).astype(np.int) for l in lab]
                print "lab_est", lab_est
                
                assert count == lab_est
                
                dataset.append((img,lab,count))
                print "img shape", img.shape
                print "label shape", lab.shape
                sys.stdout.flush()
                    
    print "writing", datasetfilename
    out = open(datasetfilename, "wb",0)
    pickle.dump(dataset, out)
    out.close()
print "DONE"
# Out:
# reading 1-32-256-1-cell2-dataset.p
# DONE

# %%
np_dataset = np.asarray(dataset)

random.shuffle(np_dataset)

np_dataset = np.rollaxis(np_dataset,1,0)
np_dataset_x = np.asarray([[n] for n in np_dataset[0]],dtype=theano.config.floatX)
np_dataset_y = np.asarray([n for n in np_dataset[1]],dtype=theano.config.floatX)
np_dataset_c = np.asarray([n for n in np_dataset[2]],dtype=theano.config.floatX)

print "np_dataset_x", np_dataset_x.shape
print "np_dataset_y", np_dataset_y.shape
print "np_dataset_c", np_dataset_c.shape
# Out:
# np_dataset_x (200, 1, 256, 256)
# np_dataset_y (200, 1, 289, 289)
# np_dataset_c (200, 1)

# %%
del np_dataset

# %%
length = len(np_dataset_x)

n = nsamples

np_dataset_x_train = np_dataset_x[0:n]
np_dataset_y_train = np_dataset_y[0:n]
np_dataset_c_train = np_dataset_c[0:n]
print "np_dataset_x_train", len(np_dataset_x_train)

np_dataset_x_valid = np_dataset_x[n:2*n]
np_dataset_y_valid = np_dataset_y[n:2*n]
np_dataset_c_valid = np_dataset_c[n:2*n]
print "np_dataset_x_valid", len(np_dataset_x_valid)

np_dataset_x_test = np_dataset_x[100:]
np_dataset_y_test = np_dataset_y[100:]
np_dataset_c_test = np_dataset_c[100:]
print "np_dataset_x_test", len(np_dataset_x_test)
# Out:
# np_dataset_x_train 32
# np_dataset_x_valid 32
# np_dataset_x_test 100

# %%
np_dataset_x_train[:4,0].shape
# Out:
# (4, 256, 256)

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Example images")
plt.imshow(np.concatenate(np_dataset_x_train[:5,0],axis=1), interpolation='none', cmap='Greys_r')

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Counts in each image")
plt.bar(range(len(np_dataset_c_train)),np_dataset_c_train);

# %%
print "Total cells in training", np.sum(np_dataset_c_train[0:], axis=0)
print "Total cells in validation", np.sum(np_dataset_c_valid[0:], axis=0)
print "Total cells in testing", np.sum(np_dataset_c_test[0:], axis=0)
# Out:
# Total cells in training [ 4567.]
# Total cells in validation [ 5171.]
# Total cells in testing [ 16977.]

# %%
#to make video: ffmpeg -i image-0-%d-cell.png -vcodec libx264 aout.mp4
def processImages(name, i):
    fig = plt.Figure(figsize=(18, 9), dpi=160)
    gcf = plt.gcf()
    gcf.set_size_inches(18, 15)
    fig.set_canvas(gcf.canvas)
    
    (img, lab, count) = dataset[i]
    
    print str(i),count
    pcount = classify([[img]], [0])[0]
    
    ef = patch_size/stride
    lab_est = [(l.sum()/(ef**2)).astype(np.int) for l in lab]
    pred_est = [(l.sum()/(ef**2)).astype(np.int) for l in pcount]
    
    print str(i),"label est ",lab_est," --> predicted est ",pred_est

    ax2 = plt.subplot2grid((2,4), (0, 0), colspan=2)
    ax3 = plt.subplot2grid((2,4), (0, 2), colspan=3)
    ax4 = plt.subplot2grid((2,4), (1, 2), colspan=3)
    ax5 = plt.subplot2grid((2,4), (1, 0), rowspan=1)
    ax6 = plt.subplot2grid((2,4), (1, 1), rowspan=1)

    ax2.set_title("Input Image")
    ax2.imshow(img, interpolation='none', cmap='Greys_r')
    ax3.set_title("Regression target, {}x{} sliding window.".format(patch_size, patch_size))
    ax3.imshow(np.concatenate((lab),axis=1), interpolation='none')
    ax4.set_title("Predicted counts")
    ax4.imshow(np.concatenate((pcount),axis=1), interpolation='none')

    ax5.set_title("Real " + str(lab_est))
    ax5.set_ylim((0, np.max(lab_est)*2))
    ax5.set_xticks(np.arange(0, noutputs, 1.0))
    ax5.bar(range(noutputs),lab_est, align='center')
    ax6.set_title("Pred " + str(pred_est))
    ax6.set_ylim((0, np.max(lab_est)*2))
    ax6.set_xticks(np.arange(0, noutputs, 1.0))
    ax6.bar(range(noutputs),pred_est, align='center')
    
    fig.savefig('images-cell/image-' + str(i) + "-" + name + '.png')

# %%
import pickle, os

directory = "network-temp/"
ext = "countception.p"

if not os.path.exists(directory):
    os.makedirs(directory)
    
def save_network(net,name):
    pkl_params = lasagne.layers.get_all_param_values(net, trainable=True)
    out = open(directory + str(name) + ext, "w", 0) #bufsize=0
    pickle.dump(pkl_params, out)
    out.close()

def load_network(net,name):
    all_param_values = pickle.load(open(directory + str(name) + ext, "r" ))
    lasagne.layers.set_all_param_values(net, all_param_values, trainable=True)

# %%
def re_init_network(net, re_seed):
    
    np.random.seed(re_seed)
    lasagne.random.set_rng(np.random.RandomState(re_seed))
    
    old = lasagne.layers.get_all_param_values(net, trainable=True)
    new = []
    for layer in old:
        shape = layer.shape
        if len(shape)<2:
            shape = (shape[0], 1)
        W= lasagne.init.GlorotUniform()(shape)
        if W.shape != layer.shape:
            W = np.squeeze(W, axis= 1)
        new.append(W)
    lasagne.layers.set_all_param_values(net, new, trainable=True)

# %%
#test accuracy
def test_perf(dataset_x, dataset_y, dataset_c):

    ef = patch_size/stride
    testpixelerrors = []
    testerrors = []
    bs = 1
    for i in range(0,len(dataset_x), bs):

        pcount = classify(dataset_x,range(i,i+bs))
        pixelerr = np.abs(pcount - dataset_y[i:i+bs]).mean(axis=(2,3))
        testpixelerrors.append(pixelerr)
        
        pred_est = (pcount/(ef**2)).sum(axis=(1,2,3))
        err = np.abs(dataset_c[i:i+bs].flatten()-pred_est)
        
        testerrors.append(err)
    
    return np.abs(testpixelerrors).mean(), np.abs(testerrors).mean()

# %%
print "Random performance"
print test_perf(np_dataset_x_train, np_dataset_y_train, np_dataset_c_train)
print test_perf(np_dataset_x_valid, np_dataset_y_valid, np_dataset_c_valid)
print test_perf(np_dataset_x_test, np_dataset_y_test, np_dataset_c_test)
# Out:
# Random performance
# (1.8529316, 126.64867)
# (2.0752869, 144.41763)
# (2.1771827, 152.22734)

# %%
re_init_network(net,seed)

# %%
target_var = T.tensor4('target')
lr = theano.shared(np.array(0.005, dtype=theano.config.floatX))

#Mean Absolute Error is computed between each count of the count map
l1_loss = T.abs_(prediction - target_var[input_var_ex])

#Mean Absolute Error is computed for the overall image prediction
ef = ((patch_size/stride)**2)
prediction_count2 =(prediction/ef).sum(axis=(2,3))
mae_loss = T.abs_(prediction_count2 - (target_var[input_var_ex]/ef).sum(axis=(2,3))) 

loss = l1_loss.mean()

params = lasagne.layers.get_all_params(net, trainable=True)
updates = lasagne.updates.adam(loss, params, learning_rate=lr)

train_fn = theano.function([input_var_ex], [loss,mae_loss], updates=updates,
                         givens={input_var:np_dataset_x_train, target_var:np_dataset_y_train})

print "DONE compiling theano functons"
# Out:
# DONE compiling theano functons

# %%
batch_size = 4

print "batch_size", batch_size
print "lr", lr.eval()

best_valid_err = 99999999
best_test_err = 99999999
datasetlength = len(np_dataset_x_train)
print "datasetlength",datasetlength

for epoch in range(1000):
    start_time = time.time()

    epoch_err_pix = []
    epoch_err_pred = []
    todo = range(datasetlength)    
    
    for i in range(0,datasetlength, batch_size):
        ex = todo[i:i+batch_size]

        train_start_time = time.time()
        err_pix,err_pred = train_fn(ex)
        train_elapsed_time = time.time() - train_start_time

        epoch_err_pix.append(err_pix)
        epoch_err_pred.append(err_pred)

    valid_pix_err, valid_err = test_perf(np_dataset_x_valid, np_dataset_y_valid, np_dataset_c_valid)

    # a threshold is used to reduce processing when we are far from the goal
    if (valid_err < 5 and valid_err < best_valid_err):
        best_valid_err = valid_err
        best_test_err = test_perf(np_dataset_x_test, np_dataset_y_test,np_dataset_c_test)
        print "OOO best test (err_pix, err_pred)", best_test_err, ", epoch",epoch
        save_network(net,"best_valid_err")


    elapsed_time = time.time() - start_time
    err = np.mean(epoch_err_pix)
    acc = np.mean(np.concatenate(epoch_err_pred))
    
    if epoch % 5 == 0:
        print "#" + str(epoch) + "# (err_pix:" + str(np.around(err,3)) + ", err_pred:" +  str(np.around(acc,3)) + "), valid (err_pix:" + str(np.around(valid_pix_err,3)) + ", err_pred:" + str(np.around(valid_err,3)) +"), (time:" + str(np.around(elapsed_time,3)) + "sec)"

    #visualize training
    #processImages(str(epoch) + '-cell',0)

print "#####", "best_test_acc", best_test_err, "stride", stride, sys.argv
# Out:
# batch_size 4
# lr 0.00499999988824
# datasetlength 32
# #0# (err_pix:1.474, err_pred:75.202), valid (err_pix:1.558, err_pred:73.346), (time:11.371sec)
# #5# (err_pix:1.2, err_pred:54.587), valid (err_pix:2.215, err_pred:163.523), (time:11.757sec)
# #10# (err_pix:0.708, err_pred:23.489), valid (err_pix:0.799, err_pred:22.636), (time:11.955sec)
# #15# (err_pix:0.591, err_pred:29.435), valid (err_pix:0.648, err_pred:20.274), (time:11.956sec)
# #20# (err_pix:0.471, err_pred:15.225), valid (err_pix:0.543, err_pred:12.843), (time:11.827sec)
# #25# (err_pix:0.417, err_pred:12.502), valid (err_pix:0.502, err_pred:11.757), (time:12.082sec)
# #30# (err_pix:0.398, err_pred:13.679), valid (err_pix:0.483, err_pred:17.233), (time:12.123sec)
# #35# (err_pix:0.382, err_pred:12.984), valid (err_pix:0.465, err_pred:16.084), (time:11.93sec)
# #40# (err_pix:0.366, err_pred:11.269), valid (err_pix:0.447, err_pred:13.05), (time:11.93sec)
# #45# (err_pix:0.355, err_pred:11.701), valid (err_pix:0.434, err_pred:13.656), (time:12.022sec)
# #50# (err_pix:0.341, err_pred:10.176), valid (err_pix:0.42, err_pred:12.318), (time:11.889sec)
# #55# (err_pix:0.345, err_pred:14.035), valid (err_pix:0.423, err_pred:18.603), (time:11.869sec)
# #60# (err_pix:0.304, err_pred:8.045), valid (err_pix:0.425, err_pred:12.368), (time:11.974sec)
# #65# (err_pix:0.292, err_pred:8.397), valid (err_pix:0.369, err_pred:9.872), (time:12.061sec)
# #70# (err_pix:0.311, err_pred:7.24), valid (err_pix:0.376, err_pred:9.601), (time:11.951sec)
# OOO best test (err_pix, err_pred) (0.35017812, 4.9412379) , epoch 71
# #75# (err_pix:0.373, err_pred:17.837), valid (err_pix:0.419, err_pred:15.224), (time:11.999sec)
# #80# (err_pix:0.305, err_pred:13.659), valid (err_pix:0.342, err_pred:9.185), (time:12.234sec)
# #85# (err_pix:0.254, err_pred:6.295), valid (err_pix:0.319, err_pred:8.246), (time:11.948sec)
# #90# (err_pix:0.241, err_pred:4.141), valid (err_pix:0.337, err_pred:17.609), (time:12.054sec)
# #95# (err_pix:0.239, err_pred:5.322), valid (err_pix:0.32, err_pred:13.37), (time:12.003sec)
# #100# (err_pix:0.253, err_pred:9.542), valid (err_pix:0.301, err_pred:7.294), (time:12.028sec)
# #105# (err_pix:0.231, err_pred:3.927), valid (err_pix:0.333, err_pred:17.651), (time:11.776sec)
# #110# (err_pix:0.228, err_pred:6.407), valid (err_pix:0.294, err_pred:6.944), (time:11.87sec)
# #115# (err_pix:0.223, err_pred:5.187), valid (err_pix:0.294, err_pred:9.438), (time:11.979sec)
# #120# (err_pix:0.217, err_pred:5.361), valid (err_pix:0.312, err_pred:15.515), (time:12.03sec)
# #125# (err_pix:0.218, err_pred:5.86), valid (err_pix:0.308, err_pred:14.937), (time:12.03sec)
# #130# (err_pix:0.221, err_pred:7.932), valid (err_pix:0.273, err_pred:5.748), (time:11.888sec)
# #135# (err_pix:0.275, err_pred:15.898), valid (err_pix:0.325, err_pred:12.74), (time:11.925sec)
# OOO best test (err_pix, err_pred) (0.30550134, 4.0229845) , epoch 138
# #140# (err_pix:0.226, err_pred:6.146), valid (err_pix:0.304, err_pred:16.064), (time:11.845sec)
# #145# (err_pix:0.227, err_pred:7.417), valid (err_pix:0.274, err_pred:7.811), (time:11.932sec)
# OOO best test (err_pix, err_pred) (0.27232876, 2.7749517) , epoch 150
# #150# (err_pix:0.212, err_pred:6.56), valid (err_pix:0.269, err_pred:3.198), (time:20.458sec)
# #155# (err_pix:0.206, err_pred:6.144), valid (err_pix:0.263, err_pred:3.501), (time:11.876sec)
# #160# (err_pix:0.199, err_pred:4.141), valid (err_pix:0.261, err_pred:3.686), (time:11.896sec)
# #165# (err_pix:0.206, err_pred:5.438), valid (err_pix:0.289, err_pred:7.162), (time:11.723sec)
# #170# (err_pix:0.199, err_pred:5.366), valid (err_pix:0.269, err_pred:9.51), (time:11.942sec)
# #175# (err_pix:0.207, err_pred:5.661), valid (err_pix:0.289, err_pred:6.581), (time:11.868sec)
# #180# (err_pix:0.197, err_pred:5.42), valid (err_pix:0.264, err_pred:6.357), (time:11.789sec)
# #185# (err_pix:0.195, err_pred:4.506), valid (err_pix:0.29, err_pred:8.355), (time:11.994sec)
# #190# (err_pix:0.191, err_pred:4.043), valid (err_pix:0.271, err_pred:5.861), (time:11.833sec)
# #195# (err_pix:0.184, err_pred:3.966), valid (err_pix:0.257, err_pred:5.931), (time:11.857sec)
# #200# (err_pix:0.178, err_pred:4.116), valid (err_pix:0.254, err_pred:4.323), (time:11.773sec)
# #205# (err_pix:0.187, err_pred:6.593), valid (err_pix:0.285, err_pred:8.593), (time:11.765sec)
# #210# (err_pix:0.178, err_pred:5.54), valid (err_pix:0.259, err_pred:5.017), (time:11.993sec)
# #215# (err_pix:0.166, err_pred:2.877), valid (err_pix:0.249, err_pred:7.646), (time:11.848sec)
# #220# (err_pix:0.168, err_pred:3.835), valid (err_pix:0.248, err_pred:5.698), (time:11.867sec)
# #225# (err_pix:0.167, err_pred:2.774), valid (err_pix:0.241, err_pred:5.681), (time:11.858sec)
# #230# (err_pix:0.158, err_pred:2.756), valid (err_pix:0.246, err_pred:3.708), (time:11.944sec)
# #235# (err_pix:0.166, err_pred:3.229), valid (err_pix:0.24, err_pred:6.864), (time:11.861sec)
# #240# (err_pix:0.156, err_pred:3.86), valid (err_pix:0.247, err_pred:5.236), (time:11.933sec)
# #245# (err_pix:0.152, err_pred:2.659), valid (err_pix:0.248, err_pred:4.465), (time:12.079sec)
# #250# (err_pix:0.175, err_pred:4.416), valid (err_pix:0.279, err_pred:9.604), (time:12.03sec)
# #255# (err_pix:0.149, err_pred:3.147), valid (err_pix:0.254, err_pred:10.267), (time:11.912sec)
# #260# (err_pix:0.148, err_pred:3.298), valid (err_pix:0.234, err_pred:6.908), (time:11.887sec)
# #265# (err_pix:0.136, err_pred:2.772), valid (err_pix:0.254, err_pred:6.996), (time:12.061sec)
# OOO best test (err_pix, err_pred) (0.2529062, 3.1278927) , epoch 268
# #270# (err_pix:0.152, err_pred:3.938), valid (err_pix:0.239, err_pred:3.815), (time:12.111sec)
# #275# (err_pix:0.163, err_pred:6.945), valid (err_pix:0.243, err_pred:8.072), (time:11.887sec)
# #280# (err_pix:0.137, err_pred:3.397), valid (err_pix:0.232, err_pred:5.568), (time:11.892sec)
# #285# (err_pix:0.137, err_pred:3.398), valid (err_pix:0.243, err_pred:4.404), (time:11.849sec)
# #290# (err_pix:0.139, err_pred:3.906), valid (err_pix:0.253, err_pred:6.707), (time:11.904sec)
# #295# (err_pix:0.225, err_pred:11.506), valid (err_pix:0.256, err_pred:7.314), (time:11.847sec)
# OOO best test (err_pix, err_pred) (0.24324283, 2.746974) , epoch 297
# #300# (err_pix:0.166, err_pred:7.167), valid (err_pix:0.234, err_pred:8.859), (time:11.831sec)
# #305# (err_pix:0.133, err_pred:3.943), valid (err_pix:0.266, err_pred:8.667), (time:11.775sec)
# #310# (err_pix:0.15, err_pred:6.824), valid (err_pix:0.265, err_pred:8.234), (time:12.187sec)
# #315# (err_pix:0.137, err_pred:5.053), valid (err_pix:0.265, err_pred:8.886), (time:11.876sec)
# OOO best test (err_pix, err_pred) (0.23956245, 2.6496563) , epoch 319
# #320# (err_pix:0.132, err_pred:3.67), valid (err_pix:0.254, err_pred:8.084), (time:11.655sec)
# #325# (err_pix:0.142, err_pred:4.512), valid (err_pix:0.225, err_pred:5.16), (time:12.011sec)
# #330# (err_pix:0.118, err_pred:2.787), valid (err_pix:0.229, err_pred:3.199), (time:12.056sec)
# #335# (err_pix:0.134, err_pred:5.337), valid (err_pix:0.25, err_pred:7.825), (time:11.934sec)
# #340# (err_pix:0.122, err_pred:3.169), valid (err_pix:0.228, err_pred:3.127), (time:12.039sec)
# #345# (err_pix:0.134, err_pred:6.044), valid (err_pix:0.221, err_pred:7.223), (time:12.017sec)
# #350# (err_pix:0.11, err_pred:1.493), valid (err_pix:0.219, err_pred:6.149), (time:11.868sec)
# #355# (err_pix:0.108, err_pred:1.553), valid (err_pix:0.217, err_pred:3.575), (time:12.133sec)
# #360# (err_pix:0.103, err_pred:2.389), valid (err_pix:0.217, err_pred:4.703), (time:12.151sec)
# #365# (err_pix:0.097, err_pred:1.835), valid (err_pix:0.219, err_pred:4.177), (time:11.808sec)
# OOO best test (err_pix, err_pred) (0.23075031, 2.3862104) , epoch 367
# #370# (err_pix:0.1, err_pred:2.674), valid (err_pix:0.242, err_pred:7.332), (time:12.001sec)
# #375# (err_pix:0.153, err_pred:6.654), valid (err_pix:0.227, err_pred:6.859), (time:11.94sec)
# #380# (err_pix:0.101, err_pred:2.773), valid (err_pix:0.221, err_pred:3.606), (time:11.966sec)
# OOO best test (err_pix, err_pred) (0.232443, 2.3002429) , epoch 381
# #385# (err_pix:0.094, err_pred:1.604), valid (err_pix:0.217, err_pred:3.07), (time:11.97sec)
# #390# (err_pix:0.092, err_pred:2.308), valid (err_pix:0.216, err_pred:4.438), (time:11.846sec)
# #395# (err_pix:0.092, err_pred:2.032), valid (err_pix:0.211, err_pred:3.554), (time:12.018sec)
# #400# (err_pix:0.13, err_pred:6.967), valid (err_pix:0.243, err_pred:13.086), (time:11.832sec)
# #405# (err_pix:0.102, err_pred:3.463), valid (err_pix:0.209, err_pred:2.783), (time:11.62sec)
# #410# (err_pix:0.124, err_pred:5.254), valid (err_pix:0.231, err_pred:10.839), (time:12.048sec)
# #415# (err_pix:0.102, err_pred:2.338), valid (err_pix:0.222, err_pred:2.906), (time:12.006sec)
# #420# (err_pix:0.137, err_pred:8.362), valid (err_pix:0.258, err_pred:7.96), (time:11.905sec)
# #425# (err_pix:0.106, err_pred:3.75), valid (err_pix:0.216, err_pred:4.717), (time:11.927sec)
# OOO best test (err_pix, err_pred) (0.23377465, 2.1433196) , epoch 428
# #430# (err_pix:0.102, err_pred:3.568), valid (err_pix:0.216, err_pred:4.805), (time:11.753sec)
# #435# (err_pix:0.093, err_pred:1.868), valid (err_pix:0.219, err_pred:7.842), (time:11.973sec)
# #440# (err_pix:0.093, err_pred:2.353), valid (err_pix:0.216, err_pred:6.544), (time:11.897sec)
# #445# (err_pix:0.103, err_pred:3.692), valid (err_pix:0.223, err_pred:9.31), (time:11.796sec)
# #450# (err_pix:0.106, err_pred:3.764), valid (err_pix:0.223, err_pred:3.223), (time:11.97sec)
# #455# (err_pix:0.124, err_pred:6.619), valid (err_pix:0.235, err_pred:10.052), (time:11.992sec)
# #460# (err_pix:0.082, err_pred:1.765), valid (err_pix:0.214, err_pred:2.491), (time:11.909sec)
# #465# (err_pix:0.082, err_pred:2.862), valid (err_pix:0.213, err_pred:6.259), (time:11.923sec)
# #470# (err_pix:0.096, err_pred:4.647), valid (err_pix:0.232, err_pred:5.721), (time:11.881sec)
# #475# (err_pix:0.096, err_pred:2.627), valid (err_pix:0.214, err_pred:2.325), (time:11.989sec)
# #480# (err_pix:0.076, err_pred:1.763), valid (err_pix:0.208, err_pred:4.018), (time:11.871sec)
# #485# (err_pix:0.087, err_pred:2.992), valid (err_pix:0.222, err_pred:9.292), (time:12.165sec)
# #490# (err_pix:0.082, err_pred:2.413), valid (err_pix:0.209, err_pred:2.995), (time:11.974sec)
# #495# (err_pix:0.092, err_pred:4.454), valid (err_pix:0.223, err_pred:8.429), (time:11.883sec)
# #500# (err_pix:0.085, err_pred:3.944), valid (err_pix:0.223, err_pred:4.268), (time:11.86sec)
# OOO best test (err_pix, err_pred) (0.23032078, 2.0615723) , epoch 503
# #505# (err_pix:0.075, err_pred:1.952), valid (err_pix:0.21, err_pred:6.329), (time:11.92sec)
# #510# (err_pix:0.098, err_pred:4.801), valid (err_pix:0.227, err_pred:9.282), (time:11.772sec)
# #515# (err_pix:0.087, err_pred:3.708), valid (err_pix:0.224, err_pred:7.599), (time:11.712sec)
# #520# (err_pix:0.074, err_pred:2.352), valid (err_pix:0.206, err_pred:3.225), (time:11.813sec)
# #525# (err_pix:0.071, err_pred:1.222), valid (err_pix:0.214, err_pred:3.156), (time:11.848sec)
# #530# (err_pix:0.084, err_pred:3.57), valid (err_pix:0.244, err_pred:6.921), (time:11.771sec)
# #535# (err_pix:0.079, err_pred:2.437), valid (err_pix:0.217, err_pred:3.705), (time:11.939sec)
# #540# (err_pix:0.088, err_pred:3.879), valid (err_pix:0.226, err_pred:7.818), (time:12.032sec)
# #545# (err_pix:0.1, err_pred:5.628), valid (err_pix:0.242, err_pred:12.845), (time:11.828sec)
# #550# (err_pix:0.071, err_pred:1.004), valid (err_pix:0.212, err_pred:4.152), (time:11.78sec)
# #555# (err_pix:0.079, err_pred:2.886), valid (err_pix:0.217, err_pred:5.64), (time:11.915sec)
# #560# (err_pix:0.101, err_pred:5.1), valid (err_pix:0.307, err_pred:15.95), (time:11.954sec)
# #565# (err_pix:0.123, err_pred:6.494), valid (err_pix:0.248, err_pred:14.115), (time:11.754sec)
# #570# (err_pix:0.079, err_pred:1.064), valid (err_pix:0.212, err_pred:4.53), (time:12.042sec)
# #575# (err_pix:0.06, err_pred:0.843), valid (err_pix:0.205, err_pred:4.687), (time:11.995sec)
# #580# (err_pix:0.078, err_pred:2.647), valid (err_pix:0.21, err_pred:6.282), (time:11.895sec)
# #585# (err_pix:0.068, err_pred:2.077), valid (err_pix:0.219, err_pred:4.0), (time:11.842sec)
# #590# (err_pix:0.13, err_pred:7.083), valid (err_pix:0.258, err_pred:15.98), (time:12.067sec)
# #595# (err_pix:0.093, err_pred:3.894), valid (err_pix:0.239, err_pred:7.334), (time:11.881sec)
# #600# (err_pix:0.075, err_pred:3.091), valid (err_pix:0.209, err_pred:7.113), (time:11.86sec)
# #605# (err_pix:0.053, err_pred:0.709), valid (err_pix:0.204, err_pred:3.165), (time:11.746sec)
# #610# (err_pix:0.055, err_pred:1.197), valid (err_pix:0.206, err_pred:3.401), (time:11.943sec)
# #615# (err_pix:0.098, err_pred:5.602), valid (err_pix:0.327, err_pred:18.628), (time:12.001sec)
# #620# (err_pix:0.077, err_pred:3.518), valid (err_pix:0.219, err_pred:10.191), (time:11.841sec)
# #625# (err_pix:0.07, err_pred:3.368), valid (err_pix:0.246, err_pred:8.621), (time:11.83sec)
# #630# (err_pix:0.067, err_pred:1.952), valid (err_pix:0.217, err_pred:7.022), (time:11.855sec)
# #635# (err_pix:0.068, err_pred:2.919), valid (err_pix:0.239, err_pred:6.685), (time:11.839sec)
# #640# (err_pix:0.067, err_pred:2.325), valid (err_pix:0.207, err_pred:5.775), (time:11.858sec)
# #645# (err_pix:0.066, err_pred:2.345), valid (err_pix:0.212, err_pred:2.371), (time:11.852sec)
# #650# (err_pix:0.058, err_pred:1.312), valid (err_pix:0.206, err_pred:2.23), (time:11.818sec)
# #655# (err_pix:0.052, err_pred:1.062), valid (err_pix:0.203, err_pred:2.449), (time:11.829sec)
# #660# (err_pix:0.069, err_pred:3.631), valid (err_pix:0.215, err_pred:8.317), (time:11.817sec)
# #665# (err_pix:0.1, err_pred:5.579), valid (err_pix:0.287, err_pred:11.037), (time:11.858sec)
# #670# (err_pix:0.078, err_pred:3.244), valid (err_pix:0.224, err_pred:9.86), (time:11.843sec)
# #675# (err_pix:0.063, err_pred:2.802), valid (err_pix:0.243, err_pred:7.896), (time:11.864sec)
# #680# (err_pix:0.065, err_pred:2.423), valid (err_pix:0.208, err_pred:5.723), (time:11.864sec)
# #685# (err_pix:0.062, err_pred:2.381), valid (err_pix:0.243, err_pred:7.886), (time:11.821sec)
# #690# (err_pix:0.08, err_pred:3.053), valid (err_pix:0.21, err_pred:5.542), (time:11.881sec)
# #695# (err_pix:0.066, err_pred:2.892), valid (err_pix:0.259, err_pred:10.74), (time:11.848sec)
# #700# (err_pix:0.072, err_pred:2.402), valid (err_pix:0.207, err_pred:4.966), (time:11.844sec)
# #705# (err_pix:0.061, err_pred:1.836), valid (err_pix:0.239, err_pred:6.455), (time:11.834sec)
# #710# (err_pix:0.059, err_pred:2.045), valid (err_pix:0.202, err_pred:2.797), (time:11.85sec)
# #715# (err_pix:0.053, err_pred:1.351), valid (err_pix:0.216, err_pred:3.097), (time:11.853sec)
# #720# (err_pix:0.051, err_pred:1.386), valid (err_pix:0.223, err_pred:4.197), (time:11.867sec)
# #725# (err_pix:0.047, err_pred:0.916), valid (err_pix:0.207, err_pred:2.405), (time:11.829sec)
# #730# (err_pix:0.054, err_pred:2.143), valid (err_pix:0.208, err_pred:3.342), (time:11.868sec)
# #735# (err_pix:0.047, err_pred:1.486), valid (err_pix:0.234, err_pred:6.662), (time:11.833sec)
# #740# (err_pix:0.047, err_pred:0.934), valid (err_pix:0.204, err_pred:2.32), (time:11.835sec)
# #745# (err_pix:0.049, err_pred:1.371), valid (err_pix:0.219, err_pred:4.246), (time:11.849sec)
# #750# (err_pix:0.066, err_pred:3.847), valid (err_pix:0.218, err_pred:9.042), (time:11.845sec)
# #755# (err_pix:0.073, err_pred:3.203), valid (err_pix:0.267, err_pred:9.719), (time:11.87sec)
# #760# (err_pix:0.071, err_pred:2.93), valid (err_pix:0.209, err_pred:4.869), (time:11.844sec)
# #765# (err_pix:0.064, err_pred:2.831), valid (err_pix:0.276, err_pred:11.73), (time:11.856sec)
# #770# (err_pix:0.07, err_pred:2.289), valid (err_pix:0.208, err_pred:5.946), (time:11.821sec)
# #775# (err_pix:0.058, err_pred:1.638), valid (err_pix:0.221, err_pred:3.617), (time:11.87sec)
# #780# (err_pix:0.05, err_pred:1.42), valid (err_pix:0.214, err_pred:2.957), (time:11.86sec)
# #785# (err_pix:0.044, err_pred:1.184), valid (err_pix:0.208, err_pred:2.739), (time:11.854sec)
# #790# (err_pix:0.051, err_pred:1.385), valid (err_pix:0.204, err_pred:2.418), (time:11.878sec)
# #795# (err_pix:0.051, err_pred:1.197), valid (err_pix:0.206, err_pred:2.447), (time:11.851sec)
# #800# (err_pix:0.045, err_pred:1.259), valid (err_pix:0.213, err_pred:3.583), (time:11.863sec)
# #805# (err_pix:0.051, err_pred:1.431), valid (err_pix:0.213, err_pred:2.643), (time:11.838sec)
# #810# (err_pix:0.079, err_pred:3.89), valid (err_pix:0.264, err_pred:10.643), (time:11.867sec)
# #815# (err_pix:0.061, err_pred:2.849), valid (err_pix:0.202, err_pred:5.174), (time:11.828sec)
# #820# (err_pix:0.057, err_pred:1.947), valid (err_pix:0.214, err_pred:3.148), (time:11.864sec)
# #825# (err_pix:0.059, err_pred:2.059), valid (err_pix:0.238, err_pred:5.767), (time:11.869sec)
# #830# (err_pix:0.05, err_pred:1.944), valid (err_pix:0.205, err_pred:3.423), (time:11.874sec)
# #835# (err_pix:0.046, err_pred:1.771), valid (err_pix:0.213, err_pred:2.604), (time:11.887sec)
# #840# (err_pix:0.038, err_pred:1.053), valid (err_pix:0.211, err_pred:2.691), (time:11.861sec)
# #845# (err_pix:0.034, err_pred:0.889), valid (err_pix:0.197, err_pred:3.511), (time:11.885sec)
# #850# (err_pix:0.06, err_pred:3.484), valid (err_pix:0.274, err_pred:11.618), (time:11.852sec)
# #855# (err_pix:0.047, err_pred:1.789), valid (err_pix:0.208, err_pred:2.993), (time:11.84sec)
# #860# (err_pix:0.047, err_pred:1.72), valid (err_pix:0.214, err_pred:2.911), (time:11.888sec)
# OOO best test (err_pix, err_pred) (0.22757532, 2.1697395) , epoch 862
# #865# (err_pix:0.047, err_pred:1.925), valid (err_pix:0.245, err_pred:7.373), (time:11.884sec)
# #870# (err_pix:0.048, err_pred:1.478), valid (err_pix:0.225, err_pred:3.413), (time:11.875sec)
# #875# (err_pix:0.048, err_pred:1.232), valid (err_pix:0.213, err_pred:2.541), (time:11.89sec)
# #880# (err_pix:0.039, err_pred:1.159), valid (err_pix:0.211, err_pred:2.703), (time:11.905sec)
# #885# (err_pix:0.05, err_pred:0.97), valid (err_pix:0.202, err_pred:2.663), (time:11.894sec)
# #890# (err_pix:0.04, err_pred:1.232), valid (err_pix:0.205, err_pred:2.957), (time:11.911sec)
# #895# (err_pix:0.042, err_pred:1.718), valid (err_pix:0.234, err_pred:7.417), (time:11.921sec)
# #900# (err_pix:0.063, err_pred:2.136), valid (err_pix:0.221, err_pred:3.126), (time:11.902sec)
# #905# (err_pix:0.058, err_pred:1.944), valid (err_pix:0.208, err_pred:2.391), (time:11.926sec)
# #910# (err_pix:0.059, err_pred:2.842), valid (err_pix:0.209, err_pred:2.378), (time:11.916sec)
# #915# (err_pix:0.049, err_pred:2.148), valid (err_pix:0.225, err_pred:4.405), (time:11.922sec)
# #920# (err_pix:0.048, err_pred:2.517), valid (err_pix:0.227, err_pred:4.792), (time:11.882sec)
# #925# (err_pix:0.067, err_pred:3.627), valid (err_pix:0.244, err_pred:7.943), (time:11.933sec)
# #930# (err_pix:0.056, err_pred:2.068), valid (err_pix:0.212, err_pred:2.722), (time:11.934sec)
# #935# (err_pix:0.047, err_pred:1.553), valid (err_pix:0.213, err_pred:2.631), (time:11.918sec)
# #940# (err_pix:0.061, err_pred:2.227), valid (err_pix:0.227, err_pred:4.254), (time:11.934sec)
# #945# (err_pix:0.064, err_pred:3.629), valid (err_pix:0.277, err_pred:9.774), (time:11.921sec)
# #950# (err_pix:0.08, err_pred:4.289), valid (err_pix:0.241, err_pred:6.606), (time:11.914sec)
# #955# (err_pix:0.067, err_pred:2.84), valid (err_pix:0.229, err_pred:4.134), (time:11.921sec)
# #960# (err_pix:0.067, err_pred:3.111), valid (err_pix:0.238, err_pred:6.483), (time:11.931sec)
# #965# (err_pix:0.087, err_pred:5.289), valid (err_pix:0.277, err_pred:8.831), (time:11.939sec)
# #970# (err_pix:0.097, err_pred:5.764), valid (err_pix:0.264, err_pred:6.836), (time:11.936sec)
# #975# (err_pix:0.094, err_pred:5.519), valid (err_pix:0.228, err_pred:3.157), (time:11.911sec)
# #980# (err_pix:0.108, err_pred:6.833), valid (err_pix:0.243, err_pred:4.807), (time:11.946sec)
# #985# (err_pix:0.123, err_pred:8.116), valid (err_pix:0.235, err_pred:7.182), (time:11.932sec)
# #990# (err_pix:0.101, err_pred:5.996), valid (err_pix:0.213, err_pred:5.246), (time:11.909sec)
# #995# (err_pix:0.098, err_pred:5.684), valid (err_pix:0.242, err_pred:12.785), (time:11.942sec)
# ##### best_test_acc (0.22757532, 2.1697395) stride 1 ['jupyter', 'jupyter', '0', '32', '1']

# %%
print "Done"
# Out:
# Done

# %%
#load best network
load_network(net,"best_valid_err")

# %%
def compute_counts(dataset_x):

    ef = patch_size/stride
    bs = 1
    ests = []
    for i in range(0,len(dataset_x), bs):
        pcount = classify(dataset_x,range(i,i+bs))
        pred_est = (pcount/(ef**2)).sum(axis=(1,2,3))        
        ests.append(pred_est)
    return ests

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Training Data")

pcounts = compute_counts(np_dataset_x_train)
plt.bar(np.arange(len(np_dataset_c_train))-0.1,np_dataset_c_train, width=0.5, label="Real Count");
plt.bar(np.arange(len(np_dataset_c_train))+0.1,pcounts, width=0.5,label="Predicted Count");
plt.tight_layout()
plt.legend()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Valid Data")

pcounts = compute_counts(np_dataset_x_valid)
plt.bar(np.arange(len(np_dataset_c_valid))-0.1,np_dataset_c_valid, width=0.5, label="Real Count");
plt.bar(np.arange(len(np_dataset_c_valid))+0.1,pcounts, width=0.5,label="Predicted Count");
plt.tight_layout()
plt.legend()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15, 5)
plt.title("Test Data")

pcounts = compute_counts(np_dataset_x_test)
plt.bar(np.arange(len(np_dataset_c_test))-0.1,np_dataset_c_test, width=0.5, label="Real Count");
plt.bar(np.arange(len(np_dataset_c_test))+0.1,pcounts, width=0.5,label="Predicted Count");
plt.tight_layout()
plt.legend()

# %%
# %matplotlib inline
processImages('test',8)
# Out:
# 8 [139]
# 8 label est  [139]  --> predicted est  [139]

# %%
# %matplotlib inline
processImages('test',1)
# Out:
# 1 [146]
# 1 label est  [146]  --> predicted est  [146]

# %%
# %matplotlib inline
processImages('test',2)
# Out:
# 2 [92]
# 2 label est  [92]  --> predicted est  [91]

# %%
# %matplotlib inline
processImages('test',3)
# Out:
# 3 [208]
# 3 label est  [208]  --> predicted est  [207]

# %%
# %matplotlib inline
processImages('test',4)
# Out:
# 4 [115]
# 4 label est  [115]  --> predicted est  [114]

# %%
# %matplotlib inline
processImages('test',5)
# Out:
# 5 [252]
# 5 label est  [252]  --> predicted est  [241]

# %%
# %matplotlib inline
processImages('test',6)
# Out:
# 6 [136]
# 6 label est  [136]  --> predicted est  [136]
